# %%
import pandas as pd 
import seaborn as sns 
import matplotlib as plt 
# %matplotlib inline
import glob
import csv
import tarfile
from tqdm import tqdm
import json
from progressive.bar import Bar

# %%
files = glob.glob('../BL_Work/openPrescribe/uncompressed/*.tar.gz')
print files
# Out:
# ['../BL_Work/openPrescribe/uncompressed/T201010PDPI BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201902PDPI BNFT.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201902CHEM SUBS.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201008ADDR BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201011PDPI BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201901ADDR BNFT.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201009PDPI BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201011ADDR BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201010ADDR BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201010CHEM SUBS.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201012ADDR BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201903PDPI BNFT.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201903CHEM SUBSv2.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201901PDPI BNFT.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201903ADDR BNFT.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201012CHEM SUBS.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201011CHEM SUBS.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201902ADDR BNFT.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201009CHEM SUBS.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201012PDPI BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201009ADDR BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201901CHEM SUBS.csv.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201008PDPI BNFT.CSV.tar.gz', '../BL_Work/openPrescribe/uncompressed/T201008CHEM SUBS.CSV.tar.gz']

# %%
def compressAllCsv(PATH):
    files_lower = glob.glob(PATH+'*.csv')
    files_upper = glob.glob(PATH+'*.CSV')
    files = files_lower + files_upper
    for f in tqdm(files): 
        fileName = f+".tar.gz"
        tf = tarfile.open(fileName,mode="w:gz")
        tf.add(f)
        tf.close()

# %%
# compressAllCsv('../BL_Work/openPrescribe/uncompressed/')

# %%
taxonomy = pd.read_csv('../BL_Work/openPrescribe/taxonomy/openprescription_taxonomy',sep='\t')

# %%
taxonomy.head()
# Out:
#                              active_inngredient_name  \
# 0                    Aluminium Hydroxide (0101010C0)
# 1  Aluminium & Magnesium & Act Simeticone (010101...
# 2     Aluminium & Magnesium & Oxetacaine (0101010N0)
# 3         Calcium Carbonate & Simeticone (0101010S0)
# 4  Co-Magaldrox(Magnesium/Aluminium Hydrox) (0101...
#
#                 taxonomy_category
# 0  1.1.1: Antacids and Simeticone
# 1  1.1.1: Antacids and Simeticone
# 2  1.1.1: Antacids and Simeticone
# 3  1.1.1: Antacids and Simeticone
# 4  1.1.1: Antacids and Simeticone

# %%
DiseaseDrugs = json.load(open('DiseasesMatched.json','rb'))

# %%
quashedDict = {}
for k in DiseaseDrugs:
    quashedDict[k] = []
    totaldrugs = []
    for l in DiseaseDrugs[k]['MatchedDrugs']:
        for element in l:
            totaldrugs.append(element.lower().strip())
    
    quashedDict[k] = list(set(totaldrugs))

# %%
quashedDict
# Out:
# {u'"Meniere\'s disease"': [u'dimenhydrinate', u'betahistine', u'streptomycin'],
#  u'"chronic+fatigue+syndrome"': [],
#  u'"crohn\'s+disease"': [u'mercaptopurine',
#   u'triamcinolone',
#   u'azathioprine',
#   u'methylprednisolone',
#   u'prednisolone',
#   u'vedolizumab',
#   u'betamethasone',
#   u'sulfasalazine',
#   u'hydrocortisone',
#   u'adalimumab',
#   u'infliximab',
#   u'methotrexate',
#   u'prednisone',
#   u'certolizumab pegol',
#   u'dexamethasone',
#   u'cortisone acetate',
#   u'bupivacaine',
#   u'mesalazine'],
#  u'"interstitial+cystitis"': [u'heparin',
#   u'pentosan polysulfate',
#   u'ciclosporin',
#   u'dimethyl sulfoxide'],
#  u'"irritable+bowel+syndrome"': [u'dicyclomine',
#   u'hyoscyamine',
#   u'pinaverium',
#   u'paroxetine',
#   u'tegaserod',
#   u'nortriptyline',
#   u'lubiprostone',
#   u'clidinium',
#   u'desipramine',
#   u'eluxadoline',
#   u'alosetron',
#   u'amitriptyline',
#   u'linaclotide',
#   u'trimebutine',
#   u'rifaximin'],
#  u'"kidney+stones"': [u'citric acid', u'magnesium carbonate', u'magaldrate'],
#  u'"multiple+sclerosis"': [u'azathioprine',
#   u'modafinil',
#   u'teriflunomide',
#   u'tetracosactide',
#   u'peginterferon beta-1a',
#   u'ocrelizumab',
#   u'methotrexate',
#   u'triamcinolone',
#   u'dantrolene',
#   u'daclizumab',
#   u'natalizumab',
#   u'dalfampridine',
#   u'dimethyl fumarate',
#   u'baclofen',
#   u'fingolimod',
#   u'amantadine',
#   u'siponimod',
#   u'prednisolone',
#   u'prednisone',
#   u'interferon beta-1a',
#   u'interferon beta-1b',
#   u'betamethasone',
#   u'bupivacaine',
#   u'corticotropin',
#   u'mitoxantrone',
#   u'glatiramer',
#   u'alemtuzumab',
#   u'cannabidiol',
#   u'cladribine'],
#  u'"sleep+apnea"': [u'solriamfetol', u'modafinil'],
#  u'bipolar': [u'lithium carbonate',
#   u'nortriptyline',
#   u'methotrimeprazine',
#   u'quetiapine',
#   u'lithium cation',
#   u'verapamil',
#   u'asenapine',
#   u'lithium citrate',
#   u'doxepin',
#   u'ziprasidone',
#   u'chlorpromazine',
#   u'fluoxetine',
#   u'clonazepam',
#   u'pramipexole',
#   u'risperidone',
#   u'carbamazepine',
#   u'maprotiline',
#   u'cariprazine',
#   u'lamotrigine',
#   u'lurasidone',
#   u'valproic acid',
#   u'aripiprazole',
#   u'loxapine',
#   u'olanzapine',
#   u'bupropion'],
#  u'dementia': [u'flupentixol',
#   u'haloperidol',
#   u'thiothixene',
#   u'nortriptyline',
#   u'methotrimeprazine',
#   u'quetiapine',
#   u'thioridazine',
#   u'trifluoperazine',
#   u'paliperidone',
#   u'prazosin',
#   u'molindone',
#   u'asenapine',
#   u'amitriptyline',
#   u'ziprasidone',
#   u'chlorpromazine',
#   u'pipotiazine',
#   u'brexpiprazole',
#   u'galantamine',
#   u'risperidone',
#   u'thioproperazine',
#   u'cariprazine',
#   u'iloperidone',
#   u'lurasidone',
#   u'aripiprazole lauroxil',
#   u'donepezil',
#   u'rivastigmine',
#   u'memantine',
#   u'clozapine',
#   u'prochlorperazine',
#   u'aripiprazole',
#   u'perphenazine',
#   u'loxapine',
#   u'olanzapine',
#   u'zuclopenthixol',
#   u'mirtazapine'],
#  u'depression': [u'paroxetine',
#   u'escitalopram',
#   u'naloxone',
#   u'selegiline',
#   u'doxapram',
#   u'amoxapine',
#   u'sertraline',
#   u'nortriptyline',
#   u'esketamine',
#   u'levomilnacipran',
#   u'oxazepam',
#   u'quetiapine',
#   u'modafinil',
#   u'edrophonium',
#   u'lithium cation',
#   u'trazodone',
#   u'trimipramine',
#   u'aripiprazole',
#   u'tranylcypromine',
#   u'perphenazine',
#   u'imipramine',
#   u'clomipramine',
#   u'alprazolam',
#   u'pindolol',
#   u'doxepin',
#   u'amitriptyline',
#   u'isocarboxazid',
#   u'chlordiazepoxide',
#   u'fluoxetine',
#   u'citalopram',
#   u'moclobemide',
#   u'brexpiprazole',
#   u'buspirone',
#   u'pipradrol',
#   u'maprotiline',
#   u'venlafaxine',
#   u'amphetamine',
#   u'duloxetine',
#   u'vortioxetine',
#   u"st. john's wort",
#   u'olanzapine',
#   u'lurasidone',
#   u'phenelzine',
#   u'desipramine',
#   u'nefazodone',
#   u'valproic acid',
#   u'vilazodone',
#   u'desvenlafaxine',
#   u'protriptyline',
#   u'fluvoxamine',
#   u'lamotrigine',
#   u'bupropion',
#   u'mirtazapine'],
#  u'diabetes': [u'dextromethorphan',
#   u'promethazine',
#   u'eprosartan',
#   u'chlorpropamide',
#   u'pioglitazone',
#   u'telmisartan',
#   u'metreleptin',
#   u'vildagliptin',
#   u'insulin pork',
#   u'insulin degludec',
#   u'candesartan cilexetil',
#   u'valsartan',
#   u'benazepril',
#   u'acarbose',
#   u'lixisenatide',
#   u'phentermine',
#   u'colesevelam',
#   u'trandolapril',
#   u'saxagliptin',
#   u'atorvastatin',
#   u'insulin lispro',
#   u'dyclonine',
#   u'rosiglitazone',
#   u'irbesartan',
#   u'exenatide',
#   u'alogliptin',
#   u'hydrocodone',
#   u'captopril',
#   u'dulaglutide',
#   u'ertugliflozin',
#   u'glipizide',
#   u'domperidone',
#   u'sitagliptin',
#   u'clofedanol',
#   u'insulin glargine',
#   u'homatropine methylbromide',
#   u'fosinopril',
#   u'canagliflozin',
#   u'guaifenesin',
#   u'ranibizumab',
#   u'albiglutide',
#   u'levomenthol',
#   u'simvastatin',
#   u'lisinopril',
#   u'metformin',
#   u'chlorphenamine',
#   u'enalaprilat',
#   u'becaplermin',
#   u'orlistat',
#   u'miglitol',
#   u'metoclopramide',
#   u'desmopressin',
#   u'glimepiride',
#   u'tolbutamide',
#   u'insulin human',
#   u'perindopril',
#   u'repaglinide',
#   u'insulin detemir',
#   u'mifepristone',
#   u'benzonatate',
#   u'linagliptin',
#   u'bromocriptine',
#   u'ramipril',
#   u'liraglutide',
#   u'glyburide',
#   u'empagliflozin',
#   u'semaglutide',
#   u'alimemazine',
#   u'aflibercept',
#   u'olmesartan',
#   u'enalapril',
#   u'pancrelipase',
#   u'quinapril',
#   u'codeine',
#   u'nateglinide',
#   u'pramlintide',
#   u'losartan',
#   u'tolazamide',
#   u'insulin aspart',
#   u'gliclazide',
#   u'choline salicylate',
#   u'hydrochlorothiazide',
#   u'insulin glulisine',
#   u'dapagliflozin'],
#  u'dysautonomia': [],
#  u'gastroparesis': [u'domperidone', u'erythromycin', u'metoclopramide'],
#  u'hypothyroidism': [u'liothyronine', u'levothyroxine'],
#  u'parkinsons': [u'ropinirole'],
#  u'psoriasis': [u'cortisone acetate',
#   u'azathioprine',
#   u'ixekizumab',
#   u'linoleic acid',
#   u'methylprednisolone',
#   u'chloramphenicol',
#   u'fluorouracil',
#   u'acitretin',
#   u'risankizumab',
#   u'diclofenac',
#   u'methotrexate',
#   u'calcipotriol',
#   u'certolizumab pegol',
#   u'glycolic acid',
#   u'clioquinol',
#   u'triamcinolone',
#   u'imiquimod',
#   u'bendazac',
#   u'ketoconazole',
#   u'ustekinumab',
#   u'selenium sulfide',
#   u'infliximab',
#   u'guselkumab',
#   u'ingenol mebutate',
#   u'sodium aurothiomalate',
#   u'apremilast',
#   u'desoximetasone',
#   u'benzoyl peroxide',
#   u'tazarotene',
#   u'prednisolone',
#   u'prednisone',
#   u'etanercept',
#   u'methoxsalen',
#   u'ciclosporin',
#   u'adalimumab',
#   u'coal tar',
#   u'betamethasone',
#   u'methyl aminolevulinate',
#   u'calcitriol',
#   u'hydrocortisone',
#   u'pimecrolimus',
#   u'silver',
#   u'bupivacaine',
#   u'dexamethasone',
#   u'corticotropin',
#   u"st. john's wort",
#   u'pyrithione',
#   u'tetracosactide',
#   u'gentamicin',
#   u'octasulfur',
#   u'tacrolimus',
#   u'spironolactone',
#   u'secukinumab',
#   u'clobetasol propionate',
#   u'salicylic acid',
#   u'brodalumab',
#   u'fluocinolone acetonide'],
#  u'rheumatoid': [u'cortisone acetate',
#   u'azathioprine',
#   u'meclofenamic acid',
#   u'sarilumab',
#   u'methylprednisolone',
#   u'golimumab',
#   u'hydrocortisone',
#   u'etodolac',
#   u'diclofenac',
#   u'ibuprofen',
#   u'methotrexate',
#   u'prednisolone',
#   u'diflunisal',
#   u'hydroxychloroquine',
#   u'sodium aurothiomalate',
#   u'triamcinolone',
#   u'sulindac',
#   u'tenoxicam',
#   u'tolmetin',
#   u'oxaprozin',
#   u'meloxicam',
#   u'denosumab',
#   u'leflunomide',
#   u'indometacin',
#   u'piroxicam',
#   u'nabumetone',
#   u'infliximab',
#   u'linoleic acid',
#   u'chloroquine',
#   u'penicillamine',
#   u'fenoprofen',
#   u'prednisone',
#   u'choline magnesium trisalicylate',
#   u'etanercept',
#   u'ciclosporin',
#   u'auranofin',
#   u'flurbiprofen',
#   u'adalimumab',
#   u'celecoxib',
#   u'rituximab',
#   u'naproxen',
#   u'certolizumab pegol',
#   u'bupivacaine',
#   u'dexamethasone',
#   u'corticotropin',
#   u'abatacept',
#   u'tofacitinib',
#   u'ranitidine',
#   u'tetracosactide',
#   u'ketoprofen',
#   u'sulfasalazine',
#   u'hydrocortisone acetate',
#   u'tacrolimus',
#   u'secukinumab',
#   u'acetylsalicylic acid',
#   u'anakinra',
#   u'tiaprofenic acid',
#   u'baricitinib',
#   u'betamethasone']}

# %%
DiseaseDict =  {
    "Allergy": ["Antihistamines", "Drugs Used In Nasal Allergy", "Food Allergy"],
    "mental_health": ["Antipsychotic Drugs", "Drugs Used for Mania and Hypomania", "Antipsychotic Depot Injections", "Hypnotics", "Other Antidepressant Drugs"],
    "virals": ["Antivirals", "Influenza", "Viral Hepatitis", "Respiratory Syncytial Virus"],
    "heart": ["Cardiac Glycosides", "Drugs For  Arrhythmias", "Cardiopulmonary Resuscitation", "Lipid-Regulating Drugs", "Oral Anticoagulants", "Other Antianginal Drugs", "Peripheral Vasodilators & Related Drugs"],
    "contraceptive": ["Combined Hormonal Contraceptives/Systems", "Emergency Contraception", "Spermicidal Contraceptives", "Progestogen-only Contraceptives"],
    "STI": ["Herpesvirus Infections", "HIV Infection"],
    "respiratory": ["Corticosteroids (Respiratory)", "Antimuscarinic Bronchodilators", "Expectorant & Demulcent Cough Prep's", "Inhalation Solutions", "Inhalational Anaesthetics", "Respiratory Stimulants", "Systemic Nasal Decongestants", "Antagonists for Respiratory Depression"],
    "diabetes": ["Diabetic Diagnostic & Monitoring Agents", "Antidiabetic Drugs", "Insulin"],
    "metabolic": ["Drugs Used in Metabolic Disorders", "Gastro-Intestinal Anti-Obesity Drugs"],
    "injury": ["Arm Sling/Bandages", "Belts", "Dusting-Powders", "Hernia Support Garments", "Prep's For Minor Cuts & Abrasions"],
    "pain": ["Neuromuscular Blocking Drugs", "Neuropathic Pain", "Non-Opioid Analgesics And Compound Prep", "Opioid Analgesics", "Other Anti-Inflammatory Preparations", "Sedative & Analgesic Peri-Operative Drgs", "Peripheral Opioid-Receptor Antagonists", "Local Anaesthetics"],
    "deaddiction": ["Nicotine Dependence", "Opioid Dependence"],
    "skin": ["Preparations For Eczema", "Preparations For Psoriasis", "Preparations For Warts And Calluses"],
    "antibiotic": ["Penicillins", "Antibacterials", "Antibacterial Preparations"]
}

# %%
# taxonomyDict = {}
# for index , row in taxonomy.iterrows():
#     active = row['active_inngredient_name'].split(' ')
#     chemCode = active[-1][active[-1].find("(")+1:active[-1].find(")")]
#     taxonomyDict[chemCode] = {}
#     components = row['taxonomy_category'].split(':')
#     taxonomyDict[chemCode]['category'] = components[1].strip()
#     taxonomyDict[chemCode]['diseaseCat'] = ''
#     for k in DiseaseDict:
#         if taxonomyDict[chemCode]['category'] in DiseaseDict[k]:
#             taxonomyDict[chemCode]['diseaseCat'] = k
#             break
#     taxonomyDict[chemCode]['BNF_Classification'] = components[0]
#     taxonomyDict[chemCode]['ChemName'] = ' '.join(active[:-1])

# %%
# taxonomyDict

# %%
# len(taxonomyDict)

# %%
# fieldnames = ['Code', 'Name', 'Category','BNF_heirarchy','Disease']
# with open('../BL_Work/openPrescribe/taxonomy/taxonomy.csv', "w") as csvfile:
#     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#     writer.writeheader()
#     for k in taxonomyDict:
#         row = {'Code': k, 'Name': taxonomyDict[k]['ChemName'] , 'Category':taxonomyDict[k]['category'] , 'BNF_heirarchy' : taxonomyDict[k]['BNF_Classification'] , 'Disease': taxonomyDict[k]['diseaseCat']}
#         writer.writerow(row)

# %%
# taxonomy_df = pd.read_csv('../BL_Work/openPrescribe/taxonomy/taxonomy.csv')

# %%
# taxonomy_df

# %%
# bnf_disease = {}
# for index, row in taxonomy_df.iterrows():
#     if not pd.isnull(row['Disease']):
#         bnf_disease[row['Code']]= row['Disease']

# %%
# bnf_disease

# %%
# Taxgroups = taxonomy_df.groupby('Disease')

# %%
def readChem(year,files):
    for f in files:
        if f.find(year)>0:
            if f.find('CHEM') > 0:
                df = pd.read_csv(f,compression='infer',header=None,skiprows=1)
                return df

def readAddress(year,files):
    for f in files:
        if f.find(year)>0:
            if f.find('ADDR') > 0:
                df = pd.read_csv(f,compression='infer',header=None,skiprows=1)
                return df

def readPrescriptions(year,files):
    for f in files:
        if f.find(year)>0:
            if f.find('PDPI') > 0:
                df = pd.read_csv(f,compression='infer',header=None,skiprows=1)
                return df

# %%
pdp = readPrescriptions('201012',files)

# %%
addr = readAddress('201012',files)

# %%
chem = readChem('201012',files)

# %%
len(addr) , len(pdp) , len(chem)
# Out:
# (10261, 10026251, 3291)

# %%
chem.head()
# Out:
#            0                                                  1          2
# 0  0101010A0  Alexitol Sodium                               ...
# 1  0101010B0  Almasilate                                    ...
# 2  0101010C0  Aluminium Hydroxide                           ...
# 3  0101010D0  Aluminium Hydroxide With Magnesium            ...
# 4  0101010E0  Hydrotalcite                                  ...

# %%
DiseaseDrugMatchDict = {}
for index , row in chem.iterrows():
    try:
        drug_components = row[1].split(' ')
    except:
        print "Found an invalid key"
        continue
    normalized_components =[k.lower().strip() for k in drug_components]
    for k in quashedDict:
        if len(set(quashedDict[k]).intersection(normalized_components)) > 0:
            DiseaseDrugMatchDict[row[0]] = {}
            if 'disease' in DiseaseDrugMatchDict[row[0]]:
                DiseaseDrugMatchDict[row[0]]['disease'].append(k)
            else:
                DiseaseDrugMatchDict[row[0]]['disease'] = []
                DiseaseDrugMatchDict[row[0]]['disease'].append(k)
            if 'chemName' not in DiseaseDrugMatchDict[row[0]]:
                DiseaseDrugMatchDict[row[0]]['chemName'] = row[1]
                
print DiseaseDrugMatchDict
# Out:
# Found an invalid key
# {'1304000K0': {'chemName': 'Dexamethasone Sodium Phosphate                              ', 'disease': [u'rheumatoid']}, '0601023Y0': {'chemName': 'Exenatide                                                   ', 'disease': [u'diabetes']}, '0305010W0': {'chemName': 'Doxapram Hydrochloride                                      ', 'disease': [u'depression']}, '0105020C0': {'chemName': 'Hydrocortisone                                              ', 'disease': [u'rheumatoid']}, '0411000E0': {'chemName': 'Rivastigmine                                                ', 'disease': [u'dementia']}, '1001010V0': {'chemName': 'Tolmetin                                                    ', 'disease': [u'rheumatoid']}, '1203040D0': {'chemName': 'Hydrocortisone Acetate                                      ', 'disease': [u'rheumatoid']}, '0403030L0': {'chemName': 'Fluvoxamine Maleate                                         ', 'disease': [u'depression']}, '0802040W0': {'chemName': 'Natalizumab                                                 ', 'disease': [u'"multiple+sclerosis"']}, '0205052P0': {'chemName': 'Losartan Potassium With Diuretic                            ', 'disease': [u'diabetes']}, '0607010B0': {'chemName': 'Bromocriptine                                               ', 'disease': [u'diabetes']}, '100101040': {'chemName': 'Tenoxicam                                                   ', 'disease': [u'rheumatoid']}, '0603020Z0': {'chemName': 'Triamcinolone Acetonide                                     ', 'disease': [u'rheumatoid']}, '0601021M0': {'chemName': 'Gliclazide                                                  ', 'disease': [u'diabetes']}, '1902070Q0': {'chemName': 'Naloxone Hydrochloride                                      ', 'disease': [u'depression']}, '0403010B0': {'chemName': 'Amitriptyline Hydrochloride                                 ', 'disease': [u'depression']}, '120101030': {'chemName': 'Silver Nitrate                                              ', 'disease': [u'psoriasis']}, '1305020T0': {'chemName': 'Tazarotene                                                  ', 'disease': [u'psoriasis']}, '0205051L0': {'chemName': 'Lisinopril                                                  ', 'disease': [u'diabetes']}, '0601023V0': {'chemName': 'Metformin Hydrochloride/Rosiglitazone                       ', 'disease': [u'diabetes']}, '0501040H0': {'chemName': 'Gentamicin Sulphate                                         ', 'disease': [u'psoriasis']}, '0402010C0': {'chemName': 'Clozapine                                                   ', 'disease': [u'dementia']}, '1104020L0': {'chemName': 'Indometacin                                                 ', 'disease': [u'rheumatoid']}, '0205040S0': {'chemName': 'Prazosin Hydrochloride                                      ', 'disease': [u'dementia']}, '0603020Q0': {'chemName': 'Prednisolone Sodium Metasulphobenzoate                      ', 'disease': [u'rheumatoid']}, '0205052I0': {'chemName': 'Irbesartan                                                  ', 'disease': [u'diabetes']}, '0406000B0': {'chemName': 'Betahistine Hydrochloride                                   ', 'disease': [u'"Meniere\'s disease"']}, '0601023M0': {'chemName': 'Miglitol                                                    ', 'disease': [u'diabetes']}, '1310011B0': {'chemName': 'Chloramphenicol                                             ', 'disease': [u'psoriasis']}, '1001010C0': {'chemName': 'Diclofenac Sodium                                           ', 'disease': [u'rheumatoid']}, '0502020A0': {'chemName': 'Ketoconazole                                                ', 'disease': [u'psoriasis']}, '0601022B0': {'chemName': 'Metformin Hydrochloride                                     ', 'disease': [u'diabetes']}, '1307000U0': {'chemName': 'Fluorouracil                                                ', 'disease': [u'psoriasis']}, '1304000W0': {'chemName': 'Hydrocortisone Butyrate                                 ...

# %%
# json.dump(DiseaseDrugMatchDict,open('ChemCodeDrugDisease.json','wb'))

# %%
pdp.head()
# Out:
#     0    1       2                3   \
# 0  Q30  5D7  A86001  1302020D0BBAAAC
# 1  Q30  5D7  A86001  1310020H0AAABAB
# 2  Q30  5D7  A86003  0101010G0AAABAB
# 3  Q30  5D7  A86003  0101010R0AAABAB
# 4  Q30  5D7  A86003  0101010R0BCAAAB
#
#                                          4     5      6      7        8   \
# 0  Conotrane_Crm                              1.0   1.76   1.65    200.0
# 1  Clotrimazole_Crm 1%                        1.0   1.52   1.43     20.0
# 2  Co-Magaldrox_Susp 195mg/220mg/5ml S/F     33.0  86.02  80.28  18520.0
# 3  Simeticone_Susp 40mg/ml S/F                3.0   7.35   6.87    150.0
# 4  Infacol_Susp 40mg/ml S/F                   3.0   9.80   9.12    200.0
#
#          9        10   11   12   13
# 0  201012.0  NE6 1SG  N/A  N/A  N/A
# 1  201012.0  NE6 1SG  N/A  N/A  N/A
# 2  201012.0  NE1 8DQ  N/A  N/A  N/A
# 3  201012.0  NE1 8DQ  N/A  N/A  N/A
# 4  201012.0  NE1 8DQ  N/A  N/A  N/A

# %%
addr.head()
# Out:
#           0       1                                         2  \
# 0  201012.0  A81002  QUEENS PARK MEDICAL CENTRE
# 1  201012.0  A81003  THE GALLAGHER PRACTICE
# 2  201012.0  A81004  WOODLANDS ROAD SURGERY
# 3  201012.0  A81005  SPRINGWOOD SURGERY
# 4  201012.0  A81006  TENNANT STREET MEDICAL PRACTICE
#
#                            3                          4  \
# 0  QUEENS PARK MEDICAL CTR    FARRER STREET
# 1  THE HEALTH CENTRE          VICTORIA ROAD
# 2  6 WOODLANDS ROAD
# 3  SPRINGWOOD SURGERY         RECTORY LANE
# 4  TENNANT ST MED PRACT       FARRER STREET
#
#                            5                          6  \
# 0  STOCKTON ON TEES           CLEVELAND
# 1  HARTLEPOOL                 CLEVELAND
# 2  MIDDLESBROUGH              CLEVELAND
# 3  GUISBOROUGH
# 4  STOCKTON ON TEES           CLEVELAND
#
#                            7  \
# 0  TS18 2AW
# 1  TS26 8DB
# 2  TS1 3BE
# 3  TS14 7DJ
# 4  TS18 2AT
#
#                                                    8
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...

# %%
import inspect
def extractPostCodesDict(addrDf):
    postcodeDict = {}
    for index,row in addrDf.iterrows():
        try:
            postcodeDict[row[1]] = row[7].strip()
        except:
            print "Found invalid entry"
    return postcodeDict

def checkIndex(index):
    if index%100 == 0:
        return True
    else:
        return False

def getPC(key , postcodeDict):
    codes = []
    for k in key:
        if k in postcodeDict:
            codes.append(postcodeDict[k])
        else:
            codes.append('')
    return pd.Series(codes,index=key.index)

def getPostcode(df,postcodeDict):
    df[10] = ''
    df[10] = df.groupby(2)[2].apply(getPC,postcodeDict)   
    return df

def getDrugFamily(key, diseaseMap):
    found = 'N/A'
    for dcode in diseaseMap: 
        if key.name.find(dcode) >= 0:
            found = dcode
            break
    drug = [found]*len(key)
    return pd.Series(drug,index=key.index)

def getDisease(key, diseaseMap):
    found = 'N/A'
    for dcode in diseaseMap: 
        if key.name.find(dcode) >= 0:
            found = diseaseMap[dcode]['disease'][0]
            break
    drug = [found]*len(key)
    return pd.Series(drug,index=key.index)

def getDrug(key, diseaseMap):
    found = 'N/A'
    for dcode in diseaseMap: 
        if key.name.find(dcode) >= 0:
            found = diseaseMap[dcode]['chemName']
            break
    drug = [found]*len(key)
    return pd.Series(drug,index=key.index)

def doImportantMappings(Df, diseaseMap):
    #BNF family
    Df[11] = ''  
    Df[11] = Df.groupby(3)[3].apply(getDrugFamily,diseaseMap)
    #Disease
    Df[12] = ''  
    Df[12] = Df.groupby(3)[3].apply(getDisease,diseaseMap)
    #Checm Name
    Df[13] = ''  
    Df[13] = Df.groupby(3)[3].apply(getDrug,diseaseMap)
    return Df

# %%
postcodes = extractPostCodesDict(addr)
# Out:
# Found invalid entry

# %%
pdp = getPostcode(pdp , postcodes)

# %%
pdp.tail()
# Out:
#            0    1       2                3   \
# 10026246  Q39  5ZW  Y02518  1001010J0AABHBH
# 10026247  Q39  5ZW  Y02518  190201000AABLBL
# 10026248  Q39  5ZW  Y02518  190203000BBAAA0
# 10026249  Q39  5ZW  Y02518  21120000145
# 10026250  NaN  NaN     NaN              NaN
#
#                                                 4    5      6      7      8   \
# 10026246  Ibuprofen_Oral Susp 100mg/5ml S/F         1.0   1.48   1.40  100.0
# 10026247  Unspec Drug Code_                         1.0  11.10  10.25  125.0
# 10026248  Homoeopathic Preparation - Proprietary    1.0   3.59   3.34  125.0
# 10026249  Vitalograph Stnd Range Peak Flow Meter H  1.0   4.75   4.41    1.0
# 10026250                                       NaN  NaN    NaN    NaN    NaN
#
#                 9        10         11          12         13
# 10026246  201012.0  TQ2 7AA  1001010J0  rheumatoid  Ibuprofen
# 10026247  201012.0  TQ2 7AA        N/A         N/A        N/A
# 10026248  201012.0  TQ2 7AA        N/A         N/A        N/A
# 10026249  201012.0  TQ2 7AA        N/A         N/A        N/A
# 10026250       NaN      NaN        NaN         NaN        NaN

# %%
postcodes['A86003']
# Out:
# 'NE1 8DQ'

# %%
pdp = doImportantMappings(pdp,DiseaseDrugMatchDict)

# %%
pdp[100:200]
# Out:
#       0    1       2                3   \
# 100  Q30  5D7  A86003  0106040M0BBAEAA
# 101  Q30  5D7  A86003  0106040R0BBAAAF
# 102  Q30  5D7  A86003  0106050B0BEAAA0
# 103  Q30  5D7  A86003  0106050S0BBABAA
# 104  Q30  5D7  A86003  0107010AAAAAAAA
# 105  Q30  5D7  A86003  0107010Z0BCAAAE
# 106  Q30  5D7  A86003  0107010Z0BCACAG
# 107  Q30  5D7  A86003  0107020F0BBAAAA
# 108  Q30  5D7  A86003  0107020F0BBABAB
# 109  Q30  5D7  A86003  0107020J0AAAEAE
# 110  Q30  5D7  A86003  0107020J0AAAFAF
# 111  Q30  5D7  A86003  0107020J0BBAAAA
# 112  Q30  5D7  A86003  0107020J0BCAAAB
# 113  Q30  5D7  A86003  0107020J0BCABAC
# 114  Q30  5D7  A86003  0107020J0BDAAAD
# 115  Q30  5D7  A86003  0107020J0BEAAAE
# 116  Q30  5D7  A86003  0107020J0BEABAF
# 117  Q30  5D7  A86003  0107020J0BGAAAG
# 118  Q30  5D7  A86003  0107020J0BHAAAJ
# 119  Q30  5D7  A86003  0107020P0BCAAAC
# 120  Q30  5D7  A86003  0107020P0BCABAD
# 121  Q30  5D7  A86003  0107040A0AAAAAA
# 122  Q30  5D7  A86003  0109010U0AAAAAA
# 123  Q30  5D7  A86003  0109010U0AAABAB
# 124  Q30  5D7  A86003  0109010U0AAAYAY
# 125  Q30  5D7  A86003  0109040N0BDABAQ
# 126  Q30  5D7  A86003  0109040N0BDADAU
# 127  Q30  5D7  A86003  0109040N0BDAFAW
# 128  Q30  5D7  A86003  0201010F0AAADAD
# 129  Q30  5D7  A86003  0201010F0AAAEAE
# ..   ...  ...     ...              ...
# 170  Q30  5D7  A86003  0204000K0AAABAB
# 171  Q30  5D7  A86003  0204000K0AAACAC
# 172  Q30  5D7  A86003  0204000N0AAACAC
# 173  Q30  5D7  A86003  0204000R0AAAAAA
# 174  Q30  5D7  A86003  0204000R0AAABAB
# 175  Q30  5D7  A86003  0204000R0AAAHAH
# 176  Q30  5D7  A86003  0204000R0AAAJAJ
# 177  Q30  5D7  A86003  0204000T0AAABAB
# 178  Q30  5D7  A86003  0204000T0AAACAC
# 179  Q30  5D7  A86003  0204000T0AAAEAE
# 180  Q30  5D7  A86003  020400060AAAAAA
# 181  Q30  5D7  A86003  020400080AAABAB
# 182  Q30  5D7  A86003  020400080AAACAC
# 183  Q30  5D7  A86003  020400080AAAEAE
# 184  Q30  5D7  A86003  020400080AAAFAF
# 185  Q30  5D7  A86003  0205010J0AAAGAG
# 186  Q30  5D7  A86003  0205010J0AAAHAH
# 187  Q30  5D7  A86003  0205010N0AAABAB
# 188  Q30  5D7  A86003  0205010U0AAAAAA
# 189  Q30  5D7  A86003  0205010Y0AAAAAA
# 190  Q30  5D7  A86003  0205020E0AAACAC
# 191  Q30  5D7  A86003  0205020H0AAADAD
# 192  Q30  5D7  A86003  0205020H0AAAEAE
# 193  Q30  5D7  A86003  0205020M0AAAAAA
# 194  Q30  5D7  A86003  0205020M0AAABAB
# 195  Q30  5D7  A86003  0205020M0AAACAC
# 196  Q30  5D7  A86003  0205040D0AAAAAA
# 197  Q30  5D7  A86003  0205040D0AAABAB
# 198  Q30  5D7  A86003  0205040D0AAACAC
# 199  Q30  5D7  A86003  0205040D0AAAQAQ
#
#                                            4      5       6       7       8   \
# 100  Movicol_Pdr Sach 13.9g (Choc)               1.0   13.36   12.34    60.0
# 101  Micralax_Micro-Enem 5ml                     5.0   37.44   34.64    96.0
# 102  Moviprep_Oral Pdr Sach                      1.0   19.74   18.24     2.0
# 103  Picolax_Pdr Sach 16.3g                      2.0   20.34   18.80    12.0
# 104  Diltiazem HCl_Crm 2% (Old)                  1.0   72.42   66.72    30.0
# 105  Anusol_Crm                                  6.0   26.37   24.48   347.0
# 106  Anusol_Suppos                               6.0   21.33   19.83   144.0
# 107  Ultraproct_Oint                             3.0   13.71   12.72    90.0
# 108  Ultraproct_Suppos                           1.0    2.15    2.01    12.0
# 109  Cinchocaine HCl/Hydrocort_Oint 0.5%/0.5%    2.0   21.15   19.54   150.0
# 110  Cinchocaine HCl/Hydrocort_Suppos 5mg/5mg    4.0   19.10   17.72   120.0
# 111  Anugesic HC_Crm                             4.0   14.84   13.80   120.0
# 112  Anusol HC_Suppos                           10.0   55.44   51.38   288.0
# 113  Anusol HC_Oint                              5.0   23.03   21.36   210.0
# 114  Proctofoam HC_Foam Aero 21.2g + Applic      1.0    6.07    5.62     1.0
# 115  Proctosedyl_Oint                            2.0   20.68   19.10    60.0
# 116  Proctosedyl_Suppos                          2.0   20.97   19.38    54.0
# 117  Xyloproct_Oint 5%/0.275%                    3.0   15.82   14.66   140.0
# 118  Perinal_P/Spy 30ml                          1.0    6.11    5.66     1.0
# 119  Scheriproct_Oint                            3.0    8.82    8.22    90.0
# 120  Scheriproct_Suppos                          1.0    1.38    1.30    12.0
# 121  Glyceryl Trinit_Oint 0.2% (Old)             2.0   50.06   46.17    40.0
# 122  Ursodeoxycholic Acid_Tab 150mg             13.0  418.57  385.89  1280.0
# 123  Ursodeoxycholic Acid_Cap 250mg             10.0  788.05  726.02  1270.0
# 124  Ursodeoxycholic Acid_Tab 300mg              2.0   90.10   83.04   204.0
# 125  Creon 25000_Cap E/C                         7.0  409.65  377.47  1450.0
# 126  Creon 10000_Cap E/C                        21.0  350.39  323.35  2710.0
# 127  Creon 40000_Cap E/C                         9.0  451.20  415.80   752.0
# 128  Digoxin_Tab 62.5mcg                        24.0   27.62   26.21   358.0
# 129  Digoxin_Tab 125mcg                        118.0   67.36   65.85  1684.0
# ..                                        ...    ...     ...     ...     ...
# 170  Metoprolol Tart_Tab 50mg                   37.0   61.81   58.15  1442.0
# 171  Metoprolol Tart_Tab 100mg                   1.0    6.36    5.89   112.0
# 172  Oxprenolol HCl_Tab 40mg                     8.0   11.20   10.57   168.0
# 173  Propranolol HCl_Cap 80mg M/R               33.0  256.05  236.87  1166.0
# 174  Propranolol HCl_Cap 160mg M/R               3.0   27.02   24.98   140.0
# 175  Propranolol HCl_Tab 10mg                   20.0   67.55   62.85  2056.0
# 176  Propranolol HCl_Tab 40mg                   54.0  107.28  100.59  3229.0
# 177  Sotalol HCl_Tab 40mg                        5.0    3.82    3.68   166.0
# 178  Sotalol HCl_Tab 80mg                       11.0   19.21   18.05   564.0
# 179  Sotalol HCl_Tab 160mg                       1.0    9.36    8.65   112.0
# 180  Celiprolol HCl_Tab 200mg                    8.0   29.43   27.37   182.0
# 181  Carvedilol_Tab 12.5mg                       4.0    2.76    2.67    56.0
# 182  Carvedilol_Tab 25mg                        19.0   51.52   48.06   784.0
# 183  Carvedilol_Tab 3.125mg                      5.0   13.20   12.32   336.0
# 184  Carvedilol_Tab 6.25mg                       3.0    6.25    5.84   140.0
# 185  Hydralazine HCl_Tab 25mg                    5.0   27.98   25.93   168.0
# 186  Hydralazine HCl_Tab 50mg                   14.0   80.01   74.14   266.0
# 187  Minoxidil_Tab 5mg                           1.0   73.87   68.06   280.0
# 188  Bosentan_Tab 62.5mg                         1.0  755.11  695.40    28.0
# 189  Sildenafil_Tab 20mg                         1.0  373.50  343.98    90.0
# 190  Clonidine HCl_Tab 100mcg                    5.0   15.12   14.09   284.0
# 191  Methyldopa_Tab 250mg                       18.0   84.65   78.53   539.0
# 192  Methyldopa_Tab 500mg                        9.0   53.24   49.32   245.0
# 193  Moxonidine_Tab 200mcg                      22.0   66.74   62.16   497.0
# 194  Moxonidine_Tab 400mcg                       6.0   30.77   28.52   172.0
# 195  Moxonidine_Tab 300mcg                       1.0    9.64    8.91    56.0
# 196  Doxazosin Mesil_Tab 1mg                    12.0    6.72    6.58   203.0
# 197  Doxazosin Mesil_Tab 2mg                    46.0   48.33   46.01  1365.0
# 198  Doxazosin Mesil_Tab 4mg                    85.0  142.01  133.48  2858.0
# 199  Doxazosin Mesil_Tab 4mg M/R                37.0  247.50  229.12  1386.0
#
#            9        10         11          12  \
# 100  201012.0  NE1 8DQ        N/A         N/A
# 101  201012.0  NE1 8DQ        N/A         N/A
# 102  201012.0  NE1 8DQ        N/A         N/A
# 103  201012.0  NE1 8DQ        N/A         N/A
# 104  201012.0  NE1 8DQ        N/A         N/A
# 105  201012.0  NE1 8DQ        N/A         N/A
# 106  201012.0  NE1 8DQ        N/A         N/A
# 107  201012.0  NE1 8DQ        N/A         N/A
# 108  201012.0  NE1 8DQ        N/A         N/A
# 109  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 110  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 111  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 112  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 113  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 114  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 115  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 116  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 117  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 118  201012.0  NE1 8DQ  0107020J0  rheumatoid
# 119  201012.0  NE1 8DQ  0107020P0  rheumatoid
# 120  201012.0  NE1 8DQ  0107020P0  rheumatoid
# 121  201012.0  NE1 8DQ        N/A         N/A
# 122  201012.0  NE1 8DQ        N/A         N/A
# 123  201012.0  NE1 8DQ        N/A         N/A
# 124  201012.0  NE1 8DQ        N/A         N/A
# 125  201012.0  NE1 8DQ        N/A         N/A
# 126  201012.0  NE1 8DQ        N/A         N/A
# 127  201012.0  NE1 8DQ        N/A         N/A
# 128  201012.0  NE1 8DQ        N/A         N/A
# 129  201012.0  NE1 8DQ        N/A         N/A
# ..        ...      ...        ...         ...
# 170  201012.0  NE1 8DQ        N/A         N/A
# 171  201012.0  NE1 8DQ        N/A         N/A
# 172  201012.0  NE1 8DQ        N/A         N/A
# 173  201012.0  NE1 8DQ        N/A         N/A
# 174  201012.0  NE1 8DQ        N/A         N/A
# 175  201012.0  NE1 8DQ        N/A         N/A
# 176  201012.0  NE1 8DQ        N/A         N/A
# 177  201012.0  NE1 8DQ        N/A         N/A
# 178  201012.0  NE1 8DQ        N/A         N/A
# 179  201012.0  NE1 8DQ        N/A         N/A
# 180  201012.0  NE1 8DQ        N/A         N/A
# 181  201012.0  NE1 8DQ        N/A         N/A
# 182  201012.0  NE1 8DQ        N/A         N/A
# 183  201012.0  NE1 8DQ        N/A         N/A
# 184  201012.0  NE1 8DQ        N/A         N/A
# 185  201012.0  NE1 8DQ        N/A         N/A
# 186  201012.0  NE1 8DQ        N/A         N/A
# 187  201012.0  NE1 8DQ        N/A         N/A
# 188  201012.0  NE1 8DQ        N/A         N/A
# 189  201012.0  NE1 8DQ        N/A         N/A
# 190  201012.0  NE1 8DQ        N/A         N/A
# 191  201012.0  NE1 8DQ        N/A         N/A
# 192  201012.0  NE1 8DQ        N/A         N/A
# 193  201012.0  NE1 8DQ        N/A         N/A
# 194  201012.0  NE1 8DQ        N/A         N/A
# 195  201012.0  NE1 8DQ        N/A         N/A
# 196  201012.0  NE1 8DQ        N/A         N/A
# 197  201012.0  NE1 8DQ        N/A         N/A
# 198  201012.0  NE1 8DQ        N/A         N/A
# 199  201012.0  NE1 8DQ        N/A         N/A
#
#                                                     13
# 100                                                N/A
# 101                                                N/A
# 102                                                N/A
# 103                                                N/A
# 104                                                N/A
# 105                                                N/A
# 106                                                N/A
# 107                                                N/A
# 108                                                N/A
# 109  Hydrocortisone                                ...
# 110  Hydrocortisone                                ...
# 111  Hydrocortisone                                ...
# 112  Hydrocortisone                                ...
# 113  Hydrocortisone                                ...
# 114  Hydrocortisone                                ...
# 115  Hydrocortisone                                ...
# 116  Hydrocortisone                                ...
# 117  Hydrocortisone                                ...
# 118  Hydrocortisone                                ...
# 119  Prednisolone                                  ...
# 120  Prednisolone                                  ...
# 121                                                N/A
# 122                                                N/A
# 123                                                N/A
# 124                                                N/A
# 125                                                N/A
# 126                                                N/A
# 127                                                N/A
# 128                                                N/A
# 129                                                N/A
# ..                                                 ...
# 170                                                N/A
# 171                                                N/A
# 172                                                N/A
# 173                                                N/A
# 174                                                N/A
# 175                                                N/A
# 176                                                N/A
# 177                                                N/A
# 178                                                N/A
# 179                                                N/A
# 180                                                N/A
# 181                                                N/A
# 182                                                N/A
# 183                                                N/A
# 184                                                N/A
# 185                                                N/A
# 186                                                N/A
# 187                                                N/A
# 188                                                N/A
# 189                                                N/A
# 190                                                N/A
# 191                                                N/A
# 192                                                N/A
# 193                                                N/A
# 194                                                N/A
# 195                                                N/A
# 196                                                N/A
# 197                                                N/A
# 198                                                N/A
# 199                                                N/A
#
# [100 rows x 14 columns]

# %%
# pdp.to_csv('../BL_Work/openPrescribe/serialized/201212.gz',compression='gzip')
