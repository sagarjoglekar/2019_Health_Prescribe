# %%
import pandas as pd
import geopandas as gp 
import json
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gp
sns.set(rc={'figure.figsize':(12,8)})
plt.style.use('default')
# %matplotlib inline
from tqdm import tqdm
import glob
import numpy as np
from scipy.stats import pearsonr
from scipy.stats import linregress
import pickle as pkl

# %%
files = glob.glob('../BL_Work/openPrescribe/savings_Impact/*.h5')
files.sort()
print files
# Out:
# ['../BL_Work/openPrescribe/savings_Impact/201406.h5', '../BL_Work/openPrescribe/savings_Impact/201407.h5', '../BL_Work/openPrescribe/savings_Impact/201408.h5', '../BL_Work/openPrescribe/savings_Impact/201409.h5', '../BL_Work/openPrescribe/savings_Impact/201410.h5', '../BL_Work/openPrescribe/savings_Impact/201411.h5', '../BL_Work/openPrescribe/savings_Impact/201412.h5', '../BL_Work/openPrescribe/savings_Impact/201501.h5', '../BL_Work/openPrescribe/savings_Impact/201502.h5', '../BL_Work/openPrescribe/savings_Impact/201503.h5', '../BL_Work/openPrescribe/savings_Impact/201504.h5', '../BL_Work/openPrescribe/savings_Impact/201505.h5', '../BL_Work/openPrescribe/savings_Impact/201506.h5', '../BL_Work/openPrescribe/savings_Impact/201507.h5', '../BL_Work/openPrescribe/savings_Impact/201508.h5', '../BL_Work/openPrescribe/savings_Impact/201509.h5', '../BL_Work/openPrescribe/savings_Impact/201510.h5', '../BL_Work/openPrescribe/savings_Impact/201511.h5', '../BL_Work/openPrescribe/savings_Impact/201512.h5', '../BL_Work/openPrescribe/savings_Impact/201601.h5', '../BL_Work/openPrescribe/savings_Impact/201602.h5', '../BL_Work/openPrescribe/savings_Impact/201603.h5', '../BL_Work/openPrescribe/savings_Impact/201604.h5', '../BL_Work/openPrescribe/savings_Impact/201605.h5', '../BL_Work/openPrescribe/savings_Impact/201606.h5', '../BL_Work/openPrescribe/savings_Impact/201607.h5', '../BL_Work/openPrescribe/savings_Impact/201608.h5', '../BL_Work/openPrescribe/savings_Impact/201609.h5', '../BL_Work/openPrescribe/savings_Impact/201610.h5', '../BL_Work/openPrescribe/savings_Impact/201611.h5', '../BL_Work/openPrescribe/savings_Impact/201612.h5', '../BL_Work/openPrescribe/savings_Impact/201701.h5', '../BL_Work/openPrescribe/savings_Impact/201702.h5', '../BL_Work/openPrescribe/savings_Impact/201703.h5', '../BL_Work/openPrescribe/savings_Impact/201704.h5', '../BL_Work/openPrescribe/savings_Impact/201705.h5', '../BL_Work/openPrescribe/savings_Impact/201706.h5', '../BL_Work/openPrescribe/savings_Impact/201707.h5', '../BL_Work/openPrescribe/savings_Impact/201708.h5', '../BL_Work/openPrescribe/savings_Impact/201709.h5', '../BL_Work/openPrescribe/savings_Impact/201710.h5', '../BL_Work/openPrescribe/savings_Impact/201711.h5', '../BL_Work/openPrescribe/savings_Impact/201712.h5', '../BL_Work/openPrescribe/savings_Impact/201801.h5', '../BL_Work/openPrescribe/savings_Impact/201802.h5', '../BL_Work/openPrescribe/savings_Impact/201803.h5', '../BL_Work/openPrescribe/savings_Impact/201804.h5', '../BL_Work/openPrescribe/savings_Impact/201805.h5', '../BL_Work/openPrescribe/savings_Impact/201806.h5', '../BL_Work/openPrescribe/savings_Impact/201807.h5', '../BL_Work/openPrescribe/savings_Impact/201808.h5', '../BL_Work/openPrescribe/savings_Impact/201809.h5', '../BL_Work/openPrescribe/savings_Impact/201810.h5', '../BL_Work/openPrescribe/savings_Impact/201811.h5', '../BL_Work/openPrescribe/savings_Impact/201812.h5', '../BL_Work/openPrescribe/savings_Impact/201901.h5', '../BL_Work/openPrescribe/savings_Impact/201902.h5', '../BL_Work/openPrescribe/savings_Impact/201903.h5', '../BL_Work/openPrescribe/savings_Impact/201904.h5', '../BL_Work/openPrescribe/savings_Impact/201905.h5', '../BL_Work/openPrescribe/savings_Impact/201906.h5']

# %%
pdp = pd.read_hdf(files[0])

# %%
# %store -r opiod_BNF
# %store -r antiDM_BNF
# %store -r opiod_BNF
# %store -r antiDep_BNF

# %%
# %store -r STD_bnf

# %%
len(STD_bnf)
# Out:
# 25

# %%
LSOA_dist = json.load(open('scratchpad/GP_LSOA_PATIENTSDIST.json','rb'))

# %%
STD_bnf.head()
# Out:
#       Unnamed: 0   BNF_code  \
# 1127        1127  0501011I0
# 1128        1128  0501011J0
# 1132        1132  0501011T0
# 1134        1134  0501011W0
# 1183        1183  0501021G0
#
#                                                    NAME UNII_drugbank
# 1127  Benzylpenicillin (Penicillin G)               ...    Q42T66VG0C
# 1128  Benzylpenicillin Sodium (Penicillin G)        ...    Q42T66VG0C
# 1132  Procaine Benzylpenicillin                     ...    Q42T66VG0C
# 1134  Benethamine Penicillin/Benzylpenicillin       ...    Q42T66VG0C
# 1183  Ceftriaxone Sodium                            ...    75J73V1629

# %%
ward_pop = pd.read_csv('scratchpad/ward_pop.csv')

# %%
GP_META = pd.read_csv('../BL_Work/epraccur.csv',header=None)
GP_META.rename(columns={0:'BP_code',
                        1:'Name',
                        2:'Grouping',
                        3:'National_geo',
                        4:'Addr1',
                        5:'Addr2',
                        6:'Addr3',
                        7: 'Addr4',
                        8:'Addr5',
                        9:'Postcode',
                        10:'Open',
                        11:'Closed',
                        12:'Status',
                        13:'Org type code',
                        14:'Commissioner',
                        15:'Join provider',
                        16:'Left provider',
                        17:'Contact',
                        18:'Null1',
                        19:'Null2',
                        20:'Null3',
                        21:'Amended',
                        22:'Null4',
                        23:'Provider',
                        24:'Null5',
                        25:'Setting',
                        26:'Null6'}, 
                 inplace=True)

# %%
Open_filtered_GPs = {}
for index,row in GP_META.iterrows():
    if row ['Setting'] == 4 and row['Status'] =='A':
        Open_filtered_GPs[row['BP_code']] = row['Postcode'].strip()

# %%
population = {}
for index, row in ward_pop.iterrows():
    population[row['Ward Code 1']] = float(row['All Ages'].replace(',',''))

# %%
population_borough = {}
for name,group in ward_pop.groupby('Local Authority'):
    population_borough[name] = 0.0
    for index , row in group.iterrows():
        population_borough[name] += float(row['All Ages'].replace(',',''))

# %%
pdp.head()
# Out:
#          Unnamed: 0    0    1       2                3  \
# 0 34712       43870  Q44  01R  N81016  0101010C0BBAAAA
#   47626       56784  Q44  01R  N81068  0101010C0BBAAAA
#   50737       59895  Q44  01R  N81084  0101010C0BBAAAA
#   55199       64357  Q44  01R  N81614  0101010C0AAAAAA
#   74259       83978  Q44  02D  N81127  0101010C0BBAAAA
#
#                                                 4    5      6      7      8  \
# 0 34712  Alu-Cap_Cap 475mg                         1.0  27.42  25.34  240.0
#   47626  Alu-Cap_Cap 475mg                         1.0  41.13  38.00  360.0
#   50737  Alu-Cap_Cap 475mg                         1.0  54.84  50.66  480.0
#   55199  Alum Hydrox_Cap 475mg                     1.0  13.71  12.66  120.0
#   74259  Alu-Cap_Cap 475mg                         1.0  38.39  35.57  336.0
#
#          ...     15         16    17   18    19  20     21        22   23  \
# 0 34712  ...  475.0  0101010C0  20.0  1.0  20.0  BB  0.115  0.110952  0.0
#   47626  ...  475.0  0101010C0  30.0  1.0  30.0  BB  0.115  0.110952  0.0
#   50737  ...  475.0  0101010C0  40.0  1.0  40.0  BB  0.115  0.110952  0.0
#   55199  ...  475.0  0101010C0  10.0  1.0  10.0  AA  0.115  0.110952  0.0
#   74259  ...  475.0  0101010C0  28.0  1.0  28.0  BB  0.115  0.110952  0.0
#
#                24
# 0 34712  1.979167
#   47626  1.319444
#   50737  0.989583
#   55199  3.958333
#   74259  1.413690
#
# [5 rows x 26 columns]

# %%
def func_ome(df,drugBNF,ome_map):
    df['presc_ome'] = df['8'] *df['15']*ome_map[drugBNF]
    return df

def calculateOME(pdp,ome_map):
    pdp['presc_ome'] = 0.0
    return pdp.groupby('3',as_index=False).apply(lambda df: func_ome(df , df.name, ome_map ))

# %store -r ome_map

opioids = pdp[pdp['3'].isin(ome_map.keys())]
opioids = calculateOME(opioids , ome_map)
# Out:
# /10TBdrive/sagarj/anaconda3/envs/env_py2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# rantadine = pdp.loc[pdp['16'] == '0601023B0']

# %%
# rantadine.head()

# %%
# min(rantadine['15'])

# %%
# opioids = pdp.loc[pdp['16'].isin(STD_bnf['BNF_code'])]
# opioids = pdp

# %%
opioids.head()
# Out:
#              Unnamed: 0    0    1       2                3  \
# 494 113277       125692  Q44  02F  N81006  040702020BBABAB
#     167785       183942  Q44  12F  N85008  040702020BBABAB
#     240901       267479  Q45  00D  A83001  040702020BBABAB
#     1347159     1525127  Q48  01V  N84014  040702020AAABAB
#     1352084     1530052  Q48  01V  N84021  040702020BBAAAA
#
#                                                     4     5       6       7  \
# 494 113277   Cyclimorph 15_Inj 1ml Amp                  1.0    1.82    1.68
#     167785   Cyclimorph 15_Inj 1ml Amp                  4.0  109.44  101.12
#     240901   Cyclimorph 15_Inj 1ml Amp                  1.0    3.65    3.48
#     1347159  Morph/Cyclizine_Inj 15mg/50mg 1ml Amp     10.0   89.36   83.05
#     1352084  Cyclimorph 10_Inj 1ml Amp                  2.0   87.70   81.02
#
#                 8  ...         16    17   18     19  20    21    22     23  \
# 494 113277    1.0  ...  040702020   1.0  1.5    1.5  BB  1.00  1.68   0.68
#     167785   60.0  ...  040702020  60.0  1.5   90.0  BB  1.00  1.68  40.80
#     240901    2.0  ...  040702020   2.0  1.5    3.0  BB  1.00  1.68   1.36
#     1347159  49.0  ...  040702020  49.0  5.0  245.0  AA  1.62  1.00   0.00
#     1352084  50.0  ...  040702020  50.0  1.0   50.0  BB  1.00  1.62  31.00
#
#                     24  presc_ome
# 494 113277   15.000000       30.0
#     167785    0.250000     1800.0
#     240901    7.500000       60.0
#     1347159   1.020408     4900.0
#     1352084   0.200000     1000.0
#
# [5 rows x 27 columns]

# %%
non_generic_opioid = opioids.loc[opioids['20']!='AA']

# %%
sum(non_generic_opioid['23'])
# Out:
# 2206821.9233728056

# %%
sum(opioids['7'])
# Out:
# 20291599.329997547

# %%
len(non_generic_opioid), len(opioids)
# Out:
# (93575, 253555)

# %%
GP_postcodes_long = {}
for name , group in non_generic_opioid.groupby('2'):
    postcode = list(set(group['10']))
    GP_postcodes_long[name] = str(postcode[0]).strip()

# %%
ward_df = pd.read_csv('../BL_Work/pcd11_par11_wd11_lad11_ew_lu.csv')

# ward_df.head()

ward_postcode_map = {}
for name, group in ward_df.groupby('wd11cd'):
    ward_postcode_map[name] = list(group['pcds'])
# Out:
# /home/sagar/anaconda3/envs/env_py2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (5,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
LSOA_savings = {}

for name, group in tqdm(non_generic_opioid.groupby('2')):
    total_saving = np.sum(group['23'])
    if name in LSOA_dist:        
        for k in LSOA_dist[name]:
            if k not in LSOA_savings:
                LSOA_savings[k] = 0.0
            LSOA_savings[k]+= float(total_saving)*float(LSOA_dist[name][k])
# Out:
# 100%|██████████| 6662/6662 [00:04<00:00, 1501.62it/s]

# %%
# %store -r Ward_prevalence
# %store -r Ward_patients
# %store -r DiseasePop_byWard

# %%
df = pd.read_csv('../BL_Work/Lower_Layer_Super_Output_Area_2011_to_Ward_2015_Lookup_in_England_and_Wales.csv')

# %%
wardMap = {}
for name , group in df.groupby('WD15CD'):
        wardMap[name] = list(group['LSOA11CD'])

# %%
boroughMap = {}
for name , group in df.groupby('LAD15NM'):
        boroughMap[name] = list(group['LSOA11CD'])

# %%
population_borough = {}
for name,group in ward_pop.groupby('Local Authority'):
    population_borough[name] = 0.0
    for index , row in group.iterrows():
        population_borough[name] += float(row['All Ages'].replace(',',''))

# %%
borough_savings_UK = {}

for k in boroughMap:
    try:
        borough_savings= np.sum([LSOA_savings[w] for w in boroughMap[k] if not np.isnan(LSOA_savings[w])])
        pop = population_borough[k]
        borough_savings_UK[k] = (float(borough_savings)/float(pop))*1000.0
        
    except:
        print "Some ward had wrong data"
# Out:
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data
# Some ward had wrong data

# %%
borough_savings_UK
# Out:
# {'Adur': 33.502830436957524,
#  'Allerdale': 46.867872587095704,
#  'Amber Valley': 21.414520601670535,
#  'Arun': 29.612475353139093,
#  'Ashfield': 38.43040172741964,
#  'Ashford': 67.8716731189959,
#  'Aylesbury Vale': 24.932180491847618,
#  'Babergh': 55.756371363501884,
#  'Barking and Dagenham': 13.401598017830006,
#  'Barnet': 15.482422413621867,
#  'Barnsley': 22.99525527011535,
#  'Barrow-in-Furness': 47.96451292114356,
#  'York': 45.17791642876091}

# %%
# %store -r cityMap 
# %store -r cityPop

# %%
# cityMap

# %%
len(cityPop)
# Out:
# 109

# %%
def calculateTemporalMetrics(all_presc, non_generic,  population_borough):
    LSOA_savings = {}
    LSOA_dosage = {}
    LSOA_costs = {}
    fail = 0.0
    for name, group in all_presc.groupby('2'):
        _total_dosage = np.sum(group['24'])
        total_dosage = np.sum(group['presc_ome'])
        total_cost = np.sum(group['7'])
        if name in LSOA_dist:        
            for k in LSOA_dist[name]:
                if k not in LSOA_dosage:
                    LSOA_dosage[k] = 0.0
                    LSOA_costs[k] = 0.0
                LSOA_dosage[k]+= float(total_dosage)*float(LSOA_dist[name][k])
                LSOA_costs[k]+= float(total_cost)*float(LSOA_dist[name][k])

    for name, group in non_generic.groupby('2'):
        total_saving = np.sum(group['23'])
        if name in LSOA_dist:        
            for k in LSOA_dist[name]:
                if k not in LSOA_savings:
                    LSOA_savings[k] = 0.0
                LSOA_savings[k]+= float(total_saving)*float(LSOA_dist[name][k])

    borough_savings_UK = {}
    borough_dosage_UK = {}
    borough_cost_UK = {}
#     for k in boroughMap:
#         try:
#             borough_savings= np.sum([LSOA_savings[w] for w in boroughMap[k] if not np.isnan(LSOA_savings[w])])
#             borough_dosages= np.sum([LSOA_dosage[w] for w in boroughMap[k] if not np.isnan(LSOA_dosage[w])])
#             borough_costs= np.sum([LSOA_costs[w] for w in boroughMap[k] if not np.isnan(LSOA_costs[w])])

#             pop = population_borough[k]
#             borough_savings_UK[k] = float(borough_savings)
#             borough_dosage_UK[k] = (float(borough_dosages)/float(pop))*1000.0
#             borough_cost_UK[k] = (float(borough_costs)/float(pop))*1000.0

#         except:
#             fail+=1

#calculate city level savings
    for k in cityMap:
        try:
            borough_savings= np.sum([LSOA_savings[w] for w in cityMap[k] if not np.isnan(LSOA_savings[w])])
            borough_dosages= np.sum([LSOA_dosage[w] for w in cityMap[k] if not np.isnan(LSOA_dosage[w])])
            borough_costs= np.sum([LSOA_costs[w] for w in cityMap[k] if not np.isnan(LSOA_costs[w])])

            pop = cityPop[k]
            borough_savings_UK[k] = float(borough_savings)
            borough_dosage_UK[k] = float(borough_dosages)
            borough_cost_UK[k] = (float(borough_costs)/float(pop))*1000.0

        except:
            fail+=1
    
    return borough_savings_UK , borough_dosage_UK , borough_cost_UK

# %%
# %store -r category_BNF_map

# %%
# category_BNF_map['Antibacterials for Systemic Use']

# %%
category_BNF_map.keys()
# Out:
# [u'Posterior Pituitary Lobe Hormones',
#  u'Curare Alkaloids',
#  u'Breast Cancer Resistance Protein Inhibitors',
#  u'Prostacyclin Analogues',
#  u'UGT1A1 Substrates',
#  u'Lactates',
#  u'Caffeine',
#  u'BCRP/ABCG2 Inhibitors',
#  u'Cytochrome P-450 CYP2B6 Inhibitors (strength unknown)',
#  u'Sucrose-specific Enzyme',
#  u'Deoxycytidine',
#  u'Histamine H2 Antagonists',
#  u'Vitamins',
#  u'Thiazide-like Diuretic',
#  u'HIV Antigens',
#  u'Microtubule Inhibition',
#  u'Arsenicals',
#  u'Phosphinic Acids',
#  u'Acyclovir',
#  u'Hydroxyquinolines',
#  u'Cytochrome P450 3A4 Inhibitors',
#  u'Vinca Alkaloids',
#  u'OCT1 substrates',
#  u'Insecticides and Repellents',
#  u'Phosphoramide Mustards',
#  u'Decreased Protein Synthesis',
#  u'OAT3/SLC22A8 Substrates',
#  u'Cytochrome P-450 CYP3A Inhibitors (strong)',
#  u'Lipopeptide Antibacterial',
#  u'Nitrofuran Derivatives',
#  u'Antibiotics, Antitubercular',
#  u'Heroin, agonists',
#  u'Protein-Lysine 6-Oxidase, antagonists & inhibitors',
#  u'Growth Inhibitors',
#  u'Insulin, Short-Acting',
#  u'Erythropoiesis-Stimulating Agents',
#  u'Phosphodiesterase 5 Inhibitors',
#  u'Calcium Chelating Activity',
#  u'Adamantanes',
#  u'Analogs/Derivatives',
#  u'Anemia, Iron-Deficiency',
#  u'Luteolytic Agents',
#  u'Antimalarials',
#  u'Adrenergic alpha-1 Receptor Antagonists',
#  u'Proto-Oncogene Proteins c-sis',
#  u'Cytochrome P-450 2C18 Inducers',
#  u'Antimigraine Preparations',
#  u'Inflammation Mediators',
#  u'Dopamine Agents',
#  u'Drugs for Treatment of Bone Diseases',
#  u'Lipids',
#  u'Glucagon-Like Peptides',
#  u'Serotonin 5-HT1 Receptor Antagonists',
#  u'Sympathomimetics, Plain',
#  u'Nitrogen Mustard Compounds',
#  u'Calculi Dissolution Agent',
#  u'Monoamine Oxidase B Inhibitors',
#  u'Nucleoside and Nucleotide Reverse Transcriptase Inhibitors',
#  u'Miscellaneous General Anesthetics',
#  u'Oxadiazoles',
#  u'Uric Acid-specific Enzyme',
#  u'Lincomycin',
#  u'Cytochrome P-450 CYP2E1 Inducers (strength unknown)',
#  u'Excitatory Amino Acid Agents',
#  u'Hypertension, Pulmonary',
#  u'Fused-Ring Compounds',
#  u'OCT2 Substrates',
#  u'Local Anesthesia',
#  u'Strophanthins',
#  u'Non Potassium Sparing Diuretics',
#  u'Cytochrome P-450 CYP1A2 Inhibitors',
#  u'Polyunsaturated Alkamides',
#  u'Furocoumarins',
#  u'Antivaricose Therapy',
#  u'Cyclosporins',
#  u'Adrenergic beta-Antagonists',
#  u'Benzamides and benzamide derivatives',
#  u'Pharmaceutical Solutions',
#  u'Non-Nucleoside Reverse Transcriptase Inhibitors',
#  u'Antidepressive Agents',
#  u'Methylprednisolone',
#  u'Butanols',
#  u'Alcohol Deterrents',
#  u'Cannabinoid Receptor Antagonists',
#  u'Pituitary Hormones',
#  u'Organothiophosphorus Compounds',
#  u'2-Chloroadenosine',
#  u'Cytochrome P-450 CYP2C19 Inducers (strong)',
#  u'Chorionic Gonadotropin',
#  u'Anti-Parkinson Drugs',
#  u'GABA Agents',
#  u'Taurine',
#  u'Thiazines',
#  u'Drugs Affecting Bone Structure and Mineralization',
#  u'Cytochrome P-450 CYP2C9 Inducers (strength unknown)',
#  u'Carbenicillin',
#  u'Phenoxyacetates',
#  u'Incretin Mimetics',
#  u'Antineoplastic Agents, Phytogenic',
#  u'Potassium',
#  u'Cytochrome P450 1A2 Inhibitors',
#  u'Agents for Treatment of Hemorrhoids and Anal Fissures for Topical Use',
#  u'Viscoelastic Substances',
#  u'Antibodies, Monoclonal, Murine-Derived',
#  u'Macrolides',
#  u'Triose Sugar Alcohols',
#  u'Androstenols',
#  u'Serotonin Receptor Antagonists',
#  u'Antihistamines for Systemic Use',
#  u'UGT1A9 substrates with narrow therapeutic index',
#  u'Laxatives',
#  u'Asparaginase',
#  u'Anticarcinogenic Agents',
#  u'Estrogen Receptor Modulators',
#  u'Isoindoles',
#  u'Benzodiazepine hypnotics and sedatives',
#  u'Sphingosine 1-phosphate Receptor Modulator',
#  u'Hypoglycemia-Associated Agents',
#  u'Citrates',
#  u'Sodium Chloride Symporter Inhibitors',
#  u'Interferon Inducers',
#  u'Decreased Platelet Production',
#  u'ortho-Aminobenzoates',
#  u'Angiotensin II receptor blockers (ARBs) and diuretics',
#  u'Respiratory Smooth Muscle Relaxants',
#  u'Alkenes',
#  u'Hematopoietic Stem Cell Mobilizer',
#  u'Progesterone Receptor Modulators',
#  u'Ditiocarb',
#  u'Cytochrome P-450 CYP2D6 Inhibitors (weak)',
#  u'Vascular Endothelial Growth Factor-directed Antibody Interactions',
#  u'Tumor Necrosis Factor Receptor Blocking Activity',
#  u'Oxytocin and Analogues',
#  u'Glycoside Hydrolases',
#  u'Aluminium Compounds',
#  u'Centrally Acting Sympathomimetics',
#  u'Reproductive Control Agents',
#  u'Choline Esters',
#  u'Cytochrome P-450 CYP3A4 Inducers',
#  u'Hydroxides',
#  u'Tetrazoles',
#  u'Catecholamines',
#  u'Verapamil and analogues',
#  u'Cholestanes',
#  u'Fatty Acid Synthesis Inhibitors',
#  u'Globulins',
#  u'UGT1A3 Inhibitors',
#  u'Smoothened Receptor Antagonists',
#  u'Selective Beta 3-adrenergic Agonists',
#  u'Enzyme Activators',
#  u'Aminoalkyl Ethers',
#  u'Alkaloids',
#  u'Gonadotropin-releasing Hormone Antagonists',
#  u'Herbs and Natural Products',
#  u'Prostaglandins',
#  u'Cytochrome P-450 CYP3A4 Inducers (weak)',
#  u'Endocrine Therapy',
#  u'Hydrocarbons, Acyclic',
#  u'Sex Hormones and Modulators of the Genital System',
#  u'Pregnen (4) Derivatives',
#  u'Platelet Activating Factor, antagonists & inhibitors',
#  u'Benzyl Compounds',
#  u'Electrolyte Solutions',
#  u'Biologics for Rheumatoid Arthritis Treatment',
#  u'Calcium Channel Blockers (Dihydropyridine)',
#  u'Incretins',
#  u'Quinolines',
#  u'Hedgehog Pathway Inhibitor',
#  u'Butyrophenone Derivatives',
#  u'Phthalimides',
#  u'Azole Antifungals',
#  u'Peptide Hormones',
#  u'Neuromuscular Agents',
#  u'Antihypertensive Agents',
#  u'Dimethylamines',
#  u'Guanidine Derivatives',
#  u'Guanylate Cyclase Activators',
#  u'Penicillin G',
#  u'Medicated Dressings',
#  u'Ethylamines',
#  u'Carbamoyl Phosphate Synthetase 1 Activator',
#  u'Fatty Acid Derivatives',
#  u'Nutritional Support',
#  u'Nicotine, antagonists & inhibitors',
#  u'Drugs Used in Erectile Dysfunction',
#  u'Specific Antirheumatic Agents',
#  u'Nicotinic Acid and Derivatives',
#  u'Antiarrhythmics, Class Ib',
#  u'Antiarrhythmics, Class Ic',
#  u'Antiarrhythmics, Class Ia',
#  u'Cytochrome P-450 CYP2C18 Substrates',
#  u'Nitroimidazole Antimicrobial',
#  u'Chlorobenzenes',
#  u'Respiratory and CNS Stimulants',
#  u'Iodine Compounds',
#  u'Emollients and Protectives',
#  u'Dopamine D2 Receptor Agonists',
#  u'Cardenolides',
#  u'Increased Epithelial Proliferation',
#  u'Zalcitabine',
#  u'Programmed Death Receptor-1 Blocking Antibody',
#  u'Cytochrome P-450 CYP2D6 Inhibitors (strong)',
#  u'Leprostatic Agents',
#  u'Chemically-Induced Disorders',
#  u'Partial Opioid Agonist/Antagonist',
#  u'Photosensitizing Agents',
#  u'Eicosanoids',
#  u'Prokinetic Agents',
#  u'UDP Glucuronosyltransferases Inhibitors',
#  u'Prostaglandins F, Synthetic',
#  u'UGT2B15 Inhibitors',
#  u'Corticosteroids, Potent (Group III)',
#  u'Sigma-1 Agonist',
#  u'Kallikreins',
#  u'Physiological Phenomena',
#  u'Fluoresceins',
#  u'Vinyl Compounds',
#  u'Aluminum Complex',
#  u'Pigments, Biological',
#  u'Dibenzoxepins',
#  u'Increased Coagulation Factor VIII Activity',
#  u'Ganciclovir',
#  u'Fertility Agents',
#  u'Thyrotropin-Releasing Hormone',
#  u'Gaucher Disease',
#  u'Drug Carriers',
#  u'Kallikreins, antagonists & inhibitors',
#  u'Bile Acid Preparations',
#  u'Polymers',
#  u'Salt Solutions',
#  u'Onium Compounds',
#  u'Calcium Channel Blockers and Diuretics',
#  u'Lactams',
#  u'Monobactams',
#  u'Cytochrome P-450 CYP3A Inducers (strong)',
#  u'Polyethylene Glycols',
#  u'Endodeoxyribonucleases',
#  u'Antimycobacterials',
#  u'Angiotensin II receptor blockers (ARBs), plain',
#  u'Cell Death Inducer',
#  u'Amrinone',
#  u'Epidermal Growth Factor Receptor Antagonist',
#  u'Immunomodulatory Agents',
#  u'Prostaglandin Antagonists',
#  u'Calcium Homeostasis',
#  u'Sympatholytic (Adrenergic Blocking) Agents',
#  u'Dihydropyridine Derivatives',
#  u'Gastrointestinal Hormones',
#  u'Photoenhancer',
#  u'Alkanesulfonates',
#  u'Hydrolytic Lysosomal Neutral Glycosphingolipid-specific Enzyme',
#  u'Loxapine',
#  u'Diet, Food, and Nutrition',
#  u'Xanthines and Adrenergics',
#  u'Antipsoriatics for Topical Use',
#  u'Antimitotic Agents',
#  u'Cytochrome P-450 CYP3A4 Inducers (strong)',
#  u'Cytochrome P-450 CYP2C8 Inhibitors (strength unknown)',
#  u'Increased Myeloid Cell Production',
#  u'Aniline Compounds',
#  u'Antimetabolites, Antineoplastic',
#  u'Lignans',
#  u'Human Platelet-derived Growth Factor',
#  u'Decreased Central Nervous System Disorganized Electrical Activity',
#  u'Natural Opium Alkaloids',
#  u'Aspartic Acid',
#  u'Isotopes',
#  u'MATE 1 Substrates',
#  u'Cytochrome P-450 CYP3A7 Inhibitors (moderate)',
#  u'Miscellaneous GI Drugs',
#  u'Cell-mediated Immunity',
#  u'Selective Immunosuppressants',
#  u'Hydrocortisone and derivatives',
#  u'Agents used to treat hypothyroidism',
#  u'Vasodilating Agents',
#  u'Digoxin, antagonists & inhibitors',
#  u'Antiseptics and Disinfectants',
#  u'Alimentary Tract and Metabolism',
#  u'Quinolones',
#  u'UGT1A9 Substrates',
#  u'Tests for Fertility Disturbances',
#  u'Papaverine and Derivatives',
#  u'Luteinizing Hormone',
#  u'Plant Oils',
#  u'Pituitary Hormones, Anterior',
#  u'Quaternary Ammonium Compounds',
#  u'Cytochrome P450 1A Inducers',
#  u'Anti-Obesity Agents',
#  u'Antirheumatic Agents',
#  u'Organic Acids',
#  u'Selective Cyclooxygenase 2 Inhibitors (NSAIDs)',
#  u'MATE 2 Substrates with a Narrow Therapeutic Index',
#  u'Triamcinolone',
#  u'Protectives Against UV-Radiation',
#  u'Anticholinergic Agents',
#  u'Hydralazine',
#  u'BCRP/ABCG2 Inducers',
#  u'Kinase Inhibitor',
#  u'Acaricides',
#  u'Ergolines',
#  u'Antacids With Antiflatulents',
#  u'Anesthetics, General',
#  u'Selective T Cell Costimulation Blocker',
#  u'Drugs Used in Addictive Disorders',
#  u'Metal divalent cations',
#  u'Renal Agents',
#  u'Cytochrome P-450 CYP3A7 Inhibitors (strength unknown)',
#  u'Selective Calcium Channel Blockers With Direct Cardiac Effects',
#  u'Miscellaneous Antidepressants',
#  u'Thiocarbamates',
#  u'Enzyme Inducing Antiepileptic Drugs',
#  u'Miscellaneous Antipsychotics',
#  u'Cytochrome P-450 CYP2C19 Inducers (unknown strength)',
#  u'Endothelin A Receptor Antagonists',
#  u'Biguanides',
#  u'Glyoxylates',
#  u'Selenium Compounds',
#  u'Anti-Infective Agents, Urinary',
#  u'Hydroxymethylglutaryl-CoA Reductase Inhibitors',
#  u'Isobutyrates',
#  u'Piperidinedione Derivatives',
#  u'Glucosylceramide Synthase Inhibitor',
#  u'Sulfuric Acids',
#  u'Vesicular Monoamine Transporter 2 Inhibitors',
#  u'Sisomicin',
#  u'Agents Acting on the Renin-Angiotensin System',
#  u'Hydroxamic Acids',
#  u'Low-Ceiling Diuretics and Potassium-Sparing Agents',
#  u'Acids, Acyclic',
#  u'Cytochrome P-450 CYP2C19 Inducers',
#  u'Methemoglobinemia Associated Agents',
#  u'Anti-Parkinson Agents (Dopamine Agonist)',
#  u'Ocular Vascular Disorder Agents',
#  u'Cytochrome P-450 CYP3A7 Inducers (weak)',
#  u'Miscellaneous Cardiac Drugs',
#  u'CTLA-4-directed Blocking Antibody',
#  u'Antihypertensives for Pulmonary Arterial Hypertension',
#  u'Glutethimide',
#  u'Inducers of Drug Clearance',
#  u'Fluorides',
#  u'Interleukin-12 Antagonist',
#  u'Botulinum Toxins',
#  u'Hydroxylamines',
#  u'Glycosaminoglycans',
#  u'Alpha-and Beta-adrenergic Agonists',
#  u'Lincosamides',
#  u'Antimigraine Agents, Miscellaneous',
#  u'Increased Platelet Production',
#  u'Oxyphenonium',
#  u'Fibrinolytic Agents',
#  u'Amiodarone',
#  u'Lyases',
#  u'Interleukin 6 Receptor Antagonists',
#  u'Caffeine and Caffeine Containing Products',
#  u'Analgesics',
#  u'Sodium Potassium Chloride Symporter Inhibitors',
#  u'Calcium, agonists',
#  u'Glycylcyclines',
#  u'Guanylate Cyclase-C Agonist',
#  u'Cardiovascular Agents',
#  u'Halogens',
#  u'Factor VIII Activator',
#  u'Nucleoside Analog Antifungal',
#  u'Cytochrome P-450 CYP2B6 Substrates with a Narrow Therapeutic Index',
#  u'Oripavine Derivatives',
#  u'Cytochrome P-450 CYP2E1 Inhibitors (strength unknown)',
#  u'4-Quinolones',
#  u'Nitrites',
#  u'Penem Antibacterial',
#  u'Food Ingredients',
#  u'Basic Lotions and Liniments',
#  u'N-Methylaspartate, antagonists & inhibitors',
#  u'Neuraminic Acids',
#  u'Muscarinic Agonists',
#  u'Tests for Diabetes',
#  u'Aluminum and magnesium containing antacids',
#  u'Benzodiazepine Antagonist',
#  u'Janus Kinases, antagonists & inhibitors',
#  u'Benzocaine',
#  u'Estradiol, agonists',
#  u'Isonipecotic Acids',
#  u'Androgen Receptor Antagonists',
#  u'Adenosine Deaminase Inhibitors',
#  u'Ethers, Chemically Close to Antihistamines',
#  u'Tretinoin',
#  u'Amino Acids, Cyclic',
#  u'Short-Acting Sulfonamides',
#  u'Interleukin-23 Antagonists',
#  u'Antiinflammatory Products for Vaginal Administration',
#  u'Antimuscarinics Antispasmodics',
#  u'Tests for Gastric Secretion',
#  u'Cytochrome P-450 CYP3A5 Inhibitors (weak)',
#  u'Miscellaneous Autonomic Drugs',
#  u'Receptors, AMPA, antagonists & inhibitors',
#  u'Ethers',
#  u'Cytochrome P-450 CYP2E1 Inducers',
#  u'Appetite Depressants',
#  u'Salicylates',
#  u'Replacement Preparations',
#  u'Diagnostic Dye',
#  u'Fatty Acids, Monounsaturated',
#  u'Oxides',
#  u'Detergents',
#  u'Lypressin',
#  u'Penicillamine and Similar Agents',
#  u'Chlorides',
#  u'Anabolic Steroids',
#  u'Pyrethrins',
#  u'Prostaglandins, Synthetic',
#  u'Amino Acids, Sulfur',
#  u'Cytochrome P-450 Enzyme Inducers',
#  u'Bromobenzoates',
#  u'Nitroso Compounds',
#  u'Pro-Opiomelanocortin',
#  u'Succinimides',
#  u'Ionophores',
#  u'OATP1B3 substrates',
#  u'UGT2B7 substrates',
#  u'Iron Compounds',
#  u'Cholinergic Agents',
#  u'Meglitinides',
#  u'Cytochrome P-450 CYP2E1 Inducers (moderate)',
#  u'Pregnenes',
#  u'Arylsulfatases',
#  u'Lincosamide Antibacterial',
#  u'Streptokinase',
#  u'Other Miscellaneous Therapeutic Agents',
#  u'Opiate Partial Agonists',
#  u'Mycobacterium tuberculosis',
#  u'Acetic Acid Derivatives and Related Substances',
#  u'Xanthine derivatives',
#  u'Osmotic Activity',
#  u'Cytochrome P-450 CYP2C9 Inhibitors (strong)',
#  u'Long-Acting Sulfonamides',
#  u'Succinimide Derivatives',
#  u'Drugs Used in Nicotine Dependence',
#  u'Reverse Transcriptase Inhibitors',
#  u'Emollients Demulcents and Protectants',
#  u'Thyroid Products',
#  u'Drugs for Urinary Frequency and Incontinence',
#  u'Anion Exchange Resins',
#  u'Neoplasm Proteins',
#  u'Heparin Binding Activity',
#  u'Tests for Bile Duct Patency',
#  u'Cardiac Stimulants Excl. Cardiac Glycosides',
#  u'Angiotensin Receptor Antagonists',
#  u'Cytochrome P-450 CYP3A4 Substrates (strength unknown)',
#  u'Tricyclics and Other Norepinephrine-reuptake Inhibitors',
#  u'Isoquinolines',
#  u'OCT2 substrates with narrow therapeutic index',
#  u'Cytochrome P-450 CYP2C9 Substrates',
#  u'Carbazoles',
#  u'First Generation Antihistamines',
#  u'Mutagens',
#  u'Pregnenediones',
#  u'Adrenal Cortex Hormones',
#  u'Lanthanum',
#  u'Antifungals for Dermatological Use',
#  u'Propulsives',
#  u'Streptogramins',
#  u'Pyrrolidinones',
#  u'Diuretics, Osmotic',
#  u'Heavy Metal Antagonists',
#  u'Keto Acids',
#  u'Nitroferricyanide Derivatives',
#  u'gamma-Aminobutyric Acid-ergic Agonist',
#  u'Benzoates',
#  u'Angiotensin II Antagonists and Diuretics',
#  u'Antibiotics, Antineoplastic',
#  u'Antiviral Agents',
#  u'Potassium Salt',
#  u'Schizophrenia',
#  u'Cytochrome P-450 CYP3A5 Inhibitors (moderate)',
#  u'CD11 Antigens',
#  u'Cytochrome P-450 CYP1A2 Inhibitors (weak)',
#  u'Serotonin 3 Receptor Antagonists',
#  u'Cholelitholytic Agents',
#  u'para-Aminobenzoates',
#  u'Ammonium Compounds',
#  u'Antiparasitic Products, Insecticides and Repellents',
#  u'Cyclopropanes',
#  u'Recombinant Human Deoxyribonuclease 1',
#  u'Glycogenolytic Hormones',
#  u'Carbamic Acid Esters',
#  u'Cytochrome P-450 CYP2C9 Inhibitors',
#  u'Central Nervous System Stimulation',
#  u'Programmed Cell Death 1 Receptor',
#  u'Aromatase Inhibitors',
#  u'Benzene Derivatives',
#  u'Corticosteroids, Very Potent (Group IV)',
#  u'Pterins',
#  u'Ketosteroids',
#  u'Tyrosine Kinase Inhibitors',
#  u'Psoralens for Topical Use',
#  u'Bodily Secretions',
#  u'Picolines',
#  u'Silver Compounds',
#  u'Aluminum Silicates',
#  u'Antivirals for treatment of HCV infections',
#  u'Anti-Gonadotropin-Releasing Hormones',
#  u'Combination Contraceptives (with Estrogen and derivatives)',
#  u'Cytochrome P-450 CYP1A2 Substrates',
#  u'Dibenzothiepins',
#  u'Antiarrhythmics, Class I',
#  u'CD11a-directed Antibody Interactions',
#  u'Rifamycin Antimycobacterial',
#  u'Norbornanes',
#  u'Azepines',
#  u'Proton-pump Inhibitors',
#  u'Platelet-reducing Agents',
#  u'Chondroitin',
#  u'Tertiary amine tricyclic antidepressants',
#  u'Arabinonucleotides',
#  u'Increased Glutathione Concentration',
#  u'Phenobarbital and similars',
#  u'Benzopyrans',
#  u'Trimethyl Ammonium Compounds',
#  u'Antiarrhythmics, Class V',
#  u'Phenothiazines',
#  u'Ganglion Blockers',
#  u'Musculo-Skeletal System',
#  u'Serine Proteases',
#  u'Bufanolides',
#  u'Norpregnanes',
#  u'Coenzymes',
#  u'Cytochrome P-450 CYP2C18 Inhibitors',
#  u'Antineovascularisation Agents',
#  u'2-Amino-1-Phenylethanol Derivatives',
#  u'Scilla Glycosides',
#  u'Diphenylbutylpiperidine Derivatives',
#  u'Corticosteroids for Systemic Use, Plain',
#  u'UGT1A3 substrates',
#  u'Antipruritics and Local Anesthetics',
#  u'P-glycoprotein inducers',
#  u'Selective Alfa-1-adrenergic Blocking Agents',
#  u'gamma-Aminobutyric Acid',
#  u'Anthracyclines',
#  u'Acetaldehyde',
#  u'Moderate Risk QTc-Prolonging Agents',
#  u'Antihelminthic',
#  u'Phenylalanine Hydroxylase Activators',
#  u'HER2 Receptor Antagonist',
#  u'Opioids',
#  u'Increased Cellular Death',
#  u'Alanine',
#  u'Adenosine',
#  u'Antibacterials for Systemic Use',
#  u'Neuraxial Anesthetics',
#  u'Morphinan Derivatives',
#  u'Insulins and Analogues for Injection, Intermediate- or Long-Acting Combined With Fast-Acting',
#  u'Agents to Treat Airway Disease',
#  u'Thrombin, analogs & derivatives',
#  u'Amino Alcohols',
#  u'MAP Kinase Kinase 1, antagonists & inhibitors',
#  u'Antiglaucoma Agents',
#  u'Miscellaneous Antiprotozoals',
#  u'Peripheral alpha-1 blockers',
#  u'Alkanesulfonic Acids',
#  u'Epithelial Sodium Channel Blockers',
#  u'Topoisomerase I Inhibitors',
#  u'Cyclooxygenase Inhibitors',
#  u'Phenanthrenes',
#  u'Antiinfectives for Treatment of Acne',
#  u'Topoisomerase Inhibitors',
#  u'Pyridazines',
#  u'Gonadal Steroid Hormones',
#  u'Tetrahydropyrimidine Derivatives',
#  u'Androgens and Estrogens',
#  u'Viral Proteins',
#  u'Cytochrome P-450 CYP2B6 Substrates',
#  u'Magnesium Compounds',
#  u'Deoxyribonucleosides',
#  u'Monoamine Oxidase A Inhibitors',
#  u'Receptors, N-Methyl-D-Aspartate',
#  u'Antiandrogens, non-steroidal',
#  u'Ocular Disorders',
#  u'Oligosaccharides',
#  u'Lymphocyte Growth Factor',
#  u'Bornanes',
#  u'Cytosine Nucleotides',
#  u'Tocolytic Agents',
#  u'Parathyroid Hormones and Analogues',
#  u'Cicatrizants',
#  u'Macrolides, Lincosamides and Streptogramins',
#  u'Thiamine, antagonists & inhibitors',
#  u'Psycholeptics',
#  u'Chlorine Compounds',
#  u'Alpha and Beta Blocking Agents',
#  u'CTLA-4-directed Antibody Interactions',
#  u'Thrombocytosis',
#  u'Anabolic Agents for Systemic Use',
#  u'Ribonucleotide Reductases, antagonists & inhibitors',
#  u'Anabolic Agents',
#  u'gamma-Aminobutyric Acid A Receptor Agonist',
#  u'Partial Cholinergic Nicotinic Agonist',
#  u'Gonadal Hormones',
#  u'Mitosis Modulators',
#  u'Appetite Stimulants',
#  u'Lipopeptides',
#  u'Allylamine Antifungal',
#  u'N-Calcium Channel Receptor Antagonists',
#  u'Resorcinols',
#  u'Fibric Acids',
#  u'Amino Sugars',
#  u'OATP1B1/SLCO1B1 Inducers',
#  u'Indazoles',
#  u'Triptans',
#  u'Macromolecular Substances',
#  u'Nephrotoxic agents',
#  u'Nitriles',
#  u'Arteriolar Vasodilation',
#  u'Insulins and Analogues for Inhalation',
#  u'Sugar Alcohols',
#  u'Hematoporphyrin Derivative',
#  u'Nasal Decongestants for Systemic Use',
#  u'Cosmetics',
#  u'Miscellaneous Antimycobacterials',
#  u'Hyaluronoglucosaminidase, antagonists & inhibitors',
#  u'Azirines',
#  u'Smoking Cessation Agents',
#  u'Nonnucleoside Reverse Transcriptase Inhibitors',
#  u'Heparin Group',
#  u'Amino Acids',
#  u'Phenylacetates',
#  u'Aprepitant and Prodrugs',
#  u'Cytochrome P-450 CYP1A2 Inducers (strong)',
#  u'Trimethoprim and Derivatives',
#  u'CD80-directed Antibody Interactions',
#  u'Androstadienes',
#  u'Serotonin 5-HT1 Receptor Agonists',
#  u'P-glycoprotein/ABCB1 Substrates',
#  u'Antifibrotic Agents',
#  u'Muscle Relaxants, Peripherally Acting Agents',
#  u'Glycolates',
#  u'Decreased Cholesterol Absorption',
#  u'mTOR Inhibitors',
#  u'Cytosine',
#  u'Aminobenzoates',
#  u'Aminopenicillins',
#  u'Amino Acids, Essential',
#  u'Interleukin-1beta, antagonists & inhibitors',
#  u'Purinergic P2Y Receptor Antagonists',
#  u'Nandrolone and esters',
#  u'Daunorubicin',
#  u'Chloramphenicol',
#  u'Cocaine, antagonists & inhibitors',
#  u'Bile Acids and Salts',
#  u'Cytochrome P-450 CYP2A6 Inhibitors',
#  u'Cytochrome P-450 CYP2C18 Inhibitors (strength unknown)',
#  u'COX-2 Inhibitors',
#  u'Phenytoin and Prodrugs',
#  u'Chymotrypsin, antagonists & inhibitors',
#  u'Anti-Anxiety Agents',
#  u'Vascular Endothelial Growth Factor Receptor 2 Antagonist',
#  u'Cytochrome P-450 CYP2C8 Inducers (weak)',
#  u'Antiandrogens and Estrogens',
#  u'Proline',
#  u'Norepinephrine Reuptake Inhibitor',
#  u'Highest Risk QTc-Prolonging Agents',
#  u'Methadone',
#  u'Vasoconstrictor Agents',
#  u'Cholestadienes',
#  u'Interleukin 1 Receptor Antagonists',
#  u'Opioids, Anilidopiperidine',
#  u'Morpholines',
#  u'Ouabain',
#  u'Parasympatholytics',
#  u'Ergot-derivative Dopamine Receptor Agonists',
#  u'Oral Hypoglycemics',
#  u'Antimicrobial Cationic Peptides',
#  u'Diphenylpropylamine Derivatives',
#  u'Ceramics',
#  u'Pregnadienes',
#  u'Lactams, Macrocyclic',
#  u'Microtubule Inhibitors',
#  u'Cytochrome P-450 CYP1A2 Substrates with a Narrow Therapeutic Index',
#  u'Solvents',
#  u'Propionates',
#  u'Kinins',
#  u'Capsaicin and Similar Agents',
#  u'Benzoxazoles',
#  u'Tacrolimus',
#  u'Cytochrome P-450 CYP2C18 Substrates with a Narrow Therapeutic Index',
#  u'Estriol',
#  u'Antiglaucoma Preparations and Miotics',
#  u'Janus Kinase Inhibitors',
#  u'Increased Large Intestinal Motility',
#  u'Mast Cell Stabilizers',
#  u'Cytochrome P-450 CYP2D6 Substrates with a Narrow Therapeutic Index',
#  u'Vascular Endothelial Growth Factor Inhibitor',
#  u'Chondroitinsulfatases',
#  u'Phosphorus Compounds',
#  u'Carboxylic Ester Hydrolases',
#  u'Salicylic Acid and Derivatives',
#  u'Polyene Antifungal',
#  u'Toxiferine',
#  u'Cytochrome P-450 CYP1A2 Inducers (unknown strength)',
#  u'CCR5 Co-receptor Antagonist',
#  u'Enzymes, Immobilized',
#  u'Capsaicin, antagonists & inhibitors',
#  u'Ketoses',
#  u'Receptor, ErbB-2, antagonists & inhibitors',
#  u'Drugs for Treatment of Hyperkalemia and Hyperphosphatemia',
#  u'Bile Acid Sequestrants',
#  u'Cholinergic Receptor Agonist',
#  u'Tissue Plasminogen Activator',
#  u'Disinfectants',
#  u'Viral Fusion Protein Inhibitors',
#  u'I.V. Solution Additives',
#  u'Sensitizers Used in Photodynamic/radiation Therapy',
#  u'Influenza A M2 Protein Inhibitor',
#  u'Genitourinary Arterial Vasodilation',
#  u'Endonucleases',
#  u'Muscle Relaxants, Centrally Acting Agents',
#  u'Cytochrome P-450 CYP2C19 Substrates with a Narrow Therapeutic Index',
#  u'Glycogen Storage Disease Type II',
#  u'Salicylic Acid Derivatives',
#  u'Sodium Compounds',
#  u'Kanamycin',
#  u'env Gene Products, Human Immunodeficiency Virus',
#  u'Propanolamines',
#  u'Bradykinin Receptor Antagonists',
#  u'alpha-Galactosidase, antagonists & inhibitors',
#  u'Receptors, Tumor Necrosis Factor',
#  u'Adjuvants, Pharmaceutic',
#  u'Cystine Disulfide Reduction',
#  u'Propiophenones',
#  u'Protein Precursors',
#  u'Abortifacient Agents',
#  u'Cloxacillin',
#  u'Reduction Activity',
#  u'Local Hemostatics',
#  u'Agents that produce neuromuscular block (indirect)',
#  u'Ticlopidine',
#  u'Partial Cholinergic Nicotinic Agonists',
#  u'Herbs (Hypotensive Properties)',
#  u'Dipeptides',
#  u'Direct Acting Antivirals',
#  u'Benzoic Acid',
#  u'Biological Factors',
#  u'Central Alpha-agonists',
#  u'Anorexigenic Agents & Respiratory and CNS Stimulants',
#  u'Decarboxylase Inhibitors',
#  u'Growth Hormone-Releasing Hormone',
#  u'General Nutrients',
#  u'Dihydroorotate Dehydrogenase Inhibitors',
#  u'Selective Beta 1-adrenergic Agonists',
#  u'Urological Agents',
#  u'Lipid Modifying Agents, Plain',
#  u'Colouring Agents',
#  u'Anti-Bacterial Agents',
#  u'Neuraminidase Inhibitors',
#  u'Lipase Inhibitors',
#  u'Cytoprotective Agent',
#  u'Glycopeptides',
#  u'UGT1A6 substrate',
#  u'Histamine H1 Antagonists, Non-Sedating',
#  u'Oximes',
#  u'Oxytocin, analogs & derivatives',
#  u'Estren Derivatives',
#  u'Pyridones',
#  u'Beta Blocking Agents, Non-Selective',
#  u'Magnesium Salts',
#  u'Increased Coagulation Factor VIII Concentration',
#  u'Purine Nucleosides',
#  u'Uterotonic agents',
#  u'Nucleoside Reverse Transcriptase Inhibitors',
#  u'Transition Elements',
#  u'Decreased Sympathetic Activity',
#  u'Enzyme Replacement Therapy',
#  u'Proto-Oncogene Proteins',
#  u'Serotonin-1b and Serotonin-1d Receptor Agonist',
#  u'Folic Acid and Derivatives',
#  u'Nitrogen Compounds',
#  u'Antihistamines for Topical Use',
#  u'Avermectines',
#  u'Fertility Agents, Female',
#  u'Sodium-glucose co-transporter 2 (SGLT2) inhibitors',
#  u'Phosphodiesterase 3 Inhibitors',
#  u'Purinergic P2 Receptor Antagonists',
#  u'Cytochrome P-450 CYP3A7 Inducers',
#  u'GABA Modulators',
#  u'Serum Globulins',
#  u'Selective Serotonin Reuptake Inhibitors',
#  u'Antifungal Agents (Vaginal)',
#  u'Nucleosides and Nucleotides',
#  u'N-substituted Glycines',
#  u'Cytochrome P-450 CYP2B6 Inducers',
#  u'Dibenzoxazepines',
#  u'Thiadiazoles',
#  u'Antifungals for Topical Use',
#  u'UGT1A1 Inducers',
#  u'Urea Cycle Disorder Agents',
#  u'Carbon Compounds, Inorganic',
#  u'Hydroxy Acids',
#  u'Gonadotropins, Pituitary',
#  u'Ethylene Imines',
#  u'Increased Uterine Smooth Muscle Contraction or Tone',
#  u'Levamisole, analogs & derivatives',
#  u'Aminoketone',
#  u'Adjuvants, Immunologic',
#  u'Leukocyte Growth Factor',
#  u'Antivertigo Preparations',
#  u'Neuromuscular Nondepolarizing Blockade',
#  u'Arabinonucleosides',
#  u'Insulins and Analogues for Injection, Long-Acting',
#  u'Drugs for Treatment of Lepra',
#  u'Progesterone and Derivatives',
#  u'Antineoplastic and Immunomodulating Agents',
#  u'Antiobesity Preparations, Excl. Diet Products',
#  u'Blood Proteins',
#  u'Amino Acids, Aromatic',
#  u'Betamethasone',
#  u'Metals, Rare Earth',
#  u'Free Radicals',
#  u'Interleukin-6 Receptor Antagonist',
#  u'Insecticides',
#  u'Decreased GI Motility',
#  u'Pituitary Hormone-Releasing Hormones',
#  u'Sigma-1 Receptor Agonists',
#  u'HER2/Neu/cerbB2 Antagonists',
#  u'Vitamin D and Analogues',
#  u'Diazepines, Oxazepines, Thiazepines and Oxepines',
#  u'Anesthetics, Intravenous',
#  u'Lanthanoid Series Elements',
#  u'Metal Chelator',
#  u'Verapamil',
#  u'Gluconates',
#  u'Thiopurine Analogs',
#  u'Benzenesulfonates',
#  u'Sulfonic Acids',
#  u'Salicylic Acid',
#  u'Proto-Oncogene Proteins B-raf, antagonists & inhibitors',
#  u'Naphthacenes',
#  u'Pyrimidine Analogues',
#  u'Natriuretic Agents',
#  u'Phosphoric Monoester Hydrolases',
#  u'Lipid Modifying Agents',
#  u'Polyamines',
#  u'Histone Deacetylase Inhibitors',
#  u'Acids',
#  u'Phenyl Ethers',
#  u'Topoisomerase II Inhibitors',
#  u'Antiparasitic Agents',
#  u'Urea',
#  u'Sensory Organs',
#  u'Histamine H1 Antagonists',
#  u'Metal cations',
#  u'Miscellaneous Anxiolytics Sedatives and Hypnotics',
#  u'EENT Drugs, Miscellaneous',
#  u'Fluids and Secretions',
#  u'Voltage-Gated Sodium Channel Blockers',
#  u'Metaproterenol',
#  u'Iodine',
#  u'Agents that reduce seizure threshold',
#  u'Chromones',
#  u'Cholinergic Agonists',
#  u'Increased Diuresis',
#  u'Bile acids and derivatives',
#  u'Thyroid Hormone Synthesis Inhibitor',
#  u'Glucosides',
#  u'Flavonoids',
#  u'UGT1A4 substrates',
#  u'Mineralocorticoid (Aldosterone) Receptor Antagonists',
#  u'Thyroid Hormone Synthesis Inhibitors',
#  u'Cytochrome P-450 CYP2D6 Inhibitors (moderate)',
#  u'Antihypoglycemic Agent',
#  u'Piperidones',
#  u'Aldehyde Dehydrogenase Inhibitor',
#  u'Estrone',
#  u'Calcium Channel Blockers',
#  u'Irrigating Solutions',
#  u'Tissue Plasminogen Activator, antagonists & inhibitors',
#  u'Peptide Fragments',
#  u'Vasoprotectives',
#  u'Contraceptives, Oral, Synthetic',
#  u'Diketopiperazines',
#  u'Acetaldehyde Dehydrogenase Inhibitors',
#  u'Uridine Phosphorylase, antagonists & inhibitors',
#  u'Immunoglobulins',
#  u'Acids, Carbocyclic',
#  u'Somatropin and Somatropin Agonists',
#  u'Dihydroxyphenylalanine',
#  u'Cholinesterase substrates',
#  u'Antiemetics and Antinauseants',
#  u'Sequestering Agents',
#  u'Adrenergic Agents',
#  u'Antiemetics',
#  u'Glucosylceramide Synthase Inhibitors',
#  u'Antithyroid agents',
#  u'Receptor, Cannabinoid, CB1, antagonists & inhibitors',
#  u'UGT1A1 substrates with narrow therapeutic index',
#  u'Hypotensive Agents',
#  u'Phthalazines',
#  u'Norgestrel',
#  u'Opioid Agonist/Antagonist',
#  u'Cytochrome P-450 CYP2C9 Inhibitors (weak)',
#  u'Mucocutaneous Epithelial Cell Growth Factor',
#  u'Boron Compounds',
#  u'BCRP/ABCG2 Substrates',
#  u'Digoxin and derivatives',
#  u'Lymphokines',
#  u'Barbiturates and Derivatives',
#  u'Coformycin',
#  u'Tetrahydronaphthalenes',
#  u'Angiotensin II Antagonists and Calcium Channel Blockers',
#  u'Urease Inhibitor',
#  u'Amphibian Venoms',
#  u'Immunologic Factors',
#  u'Antacids',
#  u'Ethers of Tropine or Tropine Derivatives',
#  u'OCT2 Inhibitors',
#  u'Antimony Compounds',
#  u'Linolenic Acids',
#  u'Membrane Fusion Proteins',
#  u'Drugs for Obstructive Airway Diseases',
#  u'Conotoxins',
#  u'N-Methylaspartate, agonists',
#  u'Amines',
#  u'Fentanyl and fentanyl analogues',
#  u'Nootropic Agents',
#  u'Cytomegalovirus Nucleoside Analog DNA Polymerase Inhibitor',
#  u'Decreased Sebaceous Gland Activity',
#  u'Oxacillin',
#  u'Folic Acid',
#  u'Peptide Hydrolases',
#  u'Cytochrome P450 3A5 Inhibitors',
#  u'Adrenergic beta-Agonists',
#  u'Belladonna and Derivatives, Plain',
#  u'Opium',
#  u'Progestins',
#  u'Cytochrome P-450 CYP2E1 Inhibitors (strong)',
#  u'Nitrogen Mustard Analogues',
#  u'Benzylidene Compounds',
#  u'Boronic Acids',
#  u'Purinergic P1 Receptor Agonists',
#  u'4-Aminobenzoic Acid',
#  u'Medicated Dressings With Antiinfectives',
#  u'Adrenergics, Inhalants',
#  u'Herpes Zoster Virus Nucleoside Analog DNA Polymerase Inhibitor',
#  u'4-Hydroxycoumarins',
#  u'Anthracycline Topoisomerase Inhibitor',
#  u'Cell Migration Inhibition',
#  u'Nitrosoureas',
#  u'Marine Toxins',
#  u'Histamine Antagonists',
#  u'Imino Sugars',
#  u'Gentamicins',
#  u'Histamine H1 Inhibitors',
#  u'NMDA Receptor Antagonists',
#  u'Flavoring Agents',
#  u'Various Alimentary Tract and Metabolism Products',
#  u'COMT Substrates',
#  u'Thrombin',
#  u'Agents causing hyperkalemia',
#  u'Estrogen Antagonists',
#  u'Yohimbine',
#  u'Cycloparaffins',
#  u'Thionucleosides',
#  u'Selective Estrogen Receptor Modulators',
#  u'Cytochrome P-450 CYP2A6 Inducers (strong)',
#  u'Humanized Monoclonal Antibody Fragment',
#  u'Cytochrome P-450 CYP3A4 Inhibitors (strength unknown)',
#  u'Androstan Derivatives',
#  u'Hexoses',
#  u'Tertiary Amines',
#  u'Lysergic Acid',
#  u'Acid Reducers',
#  u'Preparations With No Effect on Uric Acid Metabolism',
#  u'Drugs that are Mainly Renally Excreted',
#  u'Phenothiazines With Piperidine Structure',
#  u'Blood Viscosity Reducer',
#  u'Imidazolines',
#  u'Genitourinary Smooth Muscle Relaxants',
#  u'Desipramine',
#  u'Amides',
#  u'Ephedrine',
#  u'Ectoparasiticides, Incl. Scabicides, Insecticides and Repellents',
#  u'Contrast Media',
#  u'Cytochrome P-450 CYP2C8 Inducers (strength unknown)',
#  u'Secosteroids',
#  u'Disease-modifying Antirheumatic Agents',
#  u'Glucagon-like Peptide-1 (GLP-1) Agonists',
#  u'MATE 2 Substrates',
#  u'Norsteroids',
#  u'Cytochrome P-450 CYP2C19 Inhibitors (strong)',
#  u'High-Ceiling Diuretics and Potassium-Sparing Agents',
#  u'Fluoropyrimidines',
#  u'Class IV Antiarrythmics',
#  u'Cytochrome P-450 CYP2B6 Inducers (strength unknown)',
#  u'Cytochrome P450 2D6 Inducers',
#  u'Adenine Nucleotides',
#  u'Third-Generation Cephalosporins',
#  u'Potassium Channel Blockers',
#  u'Low-Ceiling Diuretics, Excl. Thiazides',
#  u'Ornithine',
#  u'Acitretin',
#  u'Standardized Chemical Allergen',
#  u'Immunoglobulin G',
#  u'Microsomal Triglyceride Transfer Protein Inhibitors',
#  ...]

# %%
# selectedKeys = ['Vitamins','Histamine H2 Antagonists','Heroin, agonists','Anemia, Iron-Deficiency','Lipids','Dopamine Agents'
#                 ,'Alcohol Deterrents','Nicotine, antagonists & inhibitors','Anti-Obesity Agents','Antibacterials for Systemic Use']
selectedKeys = ['opioids']

# %%
sorted_category = sorted(category_BNF_map.items(), key=lambda item: len(item[1]),reverse=True)

# %%
# sorted_category[30:40]

# %%
# monthly_borough_savings = {k : {} for k in selectedKeys}
# monthly_borough_dosage = {k : {} for k in selectedKeys}
# monthly_borough_costs = {k : {} for k in selectedKeys}

# %%
# monthly_borough_savings = {'opioids':{},'dep':{},'diabetes':{}}
# monthly_borough_dosage = {'opioids':{},'dep':{},'diabetes':{}}
# monthly_borough_costs = {'opioids':{},'dep':{},'diabetes':{}}


monthly_borough_savings = {'opioids':{}}
monthly_borough_dosage = {'opioids':{}}
monthly_borough_costs = {'opioids':{}}

# %%
files[19]
# Out:
# '../BL_Work/openPrescribe/savings_Impact/201601.h5'

# %% [markdown]
# # pdp = pd.read_hdf(files[15])

# %%
# for f in tqdm(files[17:29]):
# # for f in tqdm(files):
#     month = f.split('/')[-1].split('.')[0]
#     monthly_borough_savings[month] = {}
#     pdp = pd.read_hdf(f)
    
#     for k in selectedKeys:
#         df_k = pdp.loc[pdp['16'].isin(category_BNF_map[k])]
#         non_generic_k = df_k.loc[df_k['20']!='AA']
#         monthly_borough_savings[k][month], monthly_borough_dosage[k][month] ,monthly_borough_costs[k][month] = calculateTemporalMetrics(df_k , non_generic_k , population_borough)

# %%
# pkl.dump(monthly_borough_savings,open('10_Cat_savings.pkl','wb'))

# pkl.dump(monthly_borough_dosage,open('10_Cat_dosage.pkl','wb'))

# pkl.dump(monthly_borough_costs,open('10_Cat_costs.pkl','wb'))

# %%
opiod_BNF = STD_bnf

# %%
files[19:31]
# Out:
# ['../BL_Work/openPrescribe/savings_Impact/201601.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201602.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201603.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201604.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201605.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201606.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201607.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201608.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201609.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201610.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201611.h5',
#  '../BL_Work/openPrescribe/savings_Impact/201612.h5']

# %%
for f in tqdm(files):
# for f in tqdm(files[19:31]):
    month = f.split('/')[-1].split('.')[0]
    monthly_borough_savings[month] = {}
    pdp = pd.read_hdf(f)
#     opioids = pdp.loc[pdp['16'].isin(opiod_BNF['BNF_code'])] #Original opioids
    opioids = pdp[pdp['3'].isin(ome_map.keys())]
    opioids = calculateOME(opioids , ome_map) 
    
#     anti_dm = pdp.loc[pdp['16'].isin(antiDM_BNF['BNF_code'])]
#     anti_dep = pdp.loc[pdp['16'].isin(antiDep_BNF['BNF_code'])]
    
    non_generic_opioid = opioids.loc[opioids['20']!='AA']
#     non_generic_dm = anti_dm.loc[anti_dm['20']!='AA']
#     non_generic_dep = anti_dep.loc[anti_dep['20']!='AA']

    monthly_borough_savings['opioids'][month], monthly_borough_dosage['opioids'][month] ,monthly_borough_costs['opioids'][month] = calculateTemporalMetrics(opioids , non_generic_opioid , population_borough)
#     monthly_borough_savings['diabetes'][month], monthly_borough_dosage['diabetes'][month] ,monthly_borough_costs['diabetes'][month] = calculateTemporalMetrics(anti_dm , non_generic_dm , population_borough)
#     monthly_borough_savings['dep'][month], monthly_borough_dosage['dep'][month] ,monthly_borough_costs['dep'][month] = calculateTemporalMetrics(anti_dep , non_generic_dep , population_borough)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]/10TBdrive/sagarj/anaconda3/envs/env_py2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# 100%|██████████| 61/61 [51:03<00:00, 49.89s/it]

# %%
IMD_df = pd.read_csv('../BL_Work/File_7_ID_2015_All_ranks__deciles_and_scores_for_the_Indices_of_Deprivation__and_population_denominators.csv')

# %%
# IMD_df.head()

# %%
IMD_city = {}
for k in cityMap:
    city_LSOA_IMD = IMD_df[IMD_df['LSOA code (2011)'].isin(cityMap[k])]
    medianIMD_city = np.median(city_LSOA_IMD['Index of Multiple Deprivation (IMD) Score'])
    IMD_city[k] = medianIMD_city
# IMD_city
# Out:
# /home/sagar/anaconda3/envs/env_py2/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/sagar/anaconda3/envs/env_py2/lib/python2.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
cityMap
# Out:
# {'Barnsley': ['E01007344',
#   'E01007355',
#   'E01007356',
#   'E01007357',
#   'E01007358',
#   'E01007359',
#   'E01007360',
#   'E01007361',
#   'E01007362',
#   'E01007363',
#   'E01007379',
#   'E01007380',
#   'E01007381',
#   'E01007386',
#   'E01007387',
#   'E01007317',
#   'E01007318',
#   'E01007319',
#   'E01007320',
#   'E01007321',
#   'E01007322',
#   'E01007323',
#   'E01007324',
#   'E01007325',
#   'E01007326',
#   'E01007327',
#   'E01007334',
#   'E01007335',
#   'E01007336',
#   'E01007337',
#   'E01007338',
#   'E01007339',
#   'E01007340',
#   'E01007446',
#   'E01007400',
#   'E01007402',
#   'E01007403',
#   'E01007404',
#   'E01007405',
#   'E01007406',
#   'E01007408',
#   'E01007409',
#   'E01007410',
#   'E01007411',
#   'E01007413',
#   'E01007414',
#   'E01007415',
#   'E01007416',
#   'E01007417',
#   'E01007437',
#   'E01007441',
#   'E01007442',
#   'E01007443',
#   'E01007444',
#   'E01007445',
#   'E01032550',
#   'E01032551'],
#  'Basildon': ['E01021323',
#   'E01021324',
#   'E01021325',
#   'E01021326',
#   'E01021327',
#   'E01021273',
#   'E01021328',
#   'E01021274',
#   'E01021275',
#   'E01021276',
#   'E01021277',
#   'E01021278',
#   'E01021279',
#   'E01021280',
#   'E01021281',
#   'E01021282',
#   'E01021283',
#   'E01021284',
#   'E01021285',
#   'E01021286',
#   'E01021287',
#   'E01021288',
#   'E01021289',
#   'E01021290',
#   'E01021291',
#   'E01021292',
#   'E01017972',
#   'E01017973',
#   'E01017974',
#   'E01017975',
#   'E01017976',
#   'E01017977',
#   'E01017978',
#   'E01017979',
#   'E01017980',
#   'E01017983',
#   'E01017984',
#   'E01017985',
#   'E01017986',
#   'E01017987',
#   'E01017988',
#   'E01017989',
#   'E01017990',
#   'E01017991',
#   'E01017992',
#   'E01017993',
#   'E01017994',
#   'E01017995',
#   'E01017996',
#   'E01017997',
#   'E01017998',
#   'E01017999',
#   'E01017943',
#   'E01017944',
#   'E01017945',
#   'E01017946',
#   'E01017947',
#   'E01017948',
#   'E01017949',
#   'E01017950',
#   'E01017951',
#   'E01017952',
#   'E01017953',
#   'E01017954',
#   'E01017955',
#   'E01017956',
#   'E01017957',
#   'E01017958',
#   'E01017959',
#   'E01017960',
#   'E01017961',
#   'E01017962',
#   'E01017963',
#   'E01017964',
#   'E01017965',
#   'E01017966',
#   'E01017967',
#   'E01017968',
#   'E01017969',
#   'E01018000',
#   'E01018001',
#   'E01018002',
#   'E01018003',
#   'E01018005',
#   'E01018006',
#   'E01018007',
#   'E01018008',
#   'E01018009',
#   'E01018010',
#   'E01018287',
#   'E01018242',
#   'E01018243',
#   'E01018244',
#   'E01018292',
#   'E01018293',
#   'E01018294',
#   'E01018248',
#   'E01018295',
#   'E01018272',
#   'E01018273',
#   'E01018274',
#   'E01033120',
#   'E01033121',
#   'E01032792',
#   'E01032794',
#   'E01032795',
#   'E01032797',
#   'E01032802'],
#  'Cardiff': ['W01001861',
#   'W01001809',
#   'W01001862',
#   'W01001863',
#   'W01001864',
#   'W01001810',
#   'W01001865',
#   'W01001811',
#   'W01001866',
#   'W01001812',
#   'W01001867',
#   'W01001813',
#   'W01001704',
#   'W01001868',
#   'W01001814',
#   'W01001705',
#   'W01001756',
#   'W01001869',
#   'W01001815',
#   'W01001706',
#   'W01001757',
#   'W01001870',
#   'W01001816',
#   'W01001707',
#   'W01001758',
#   'W01001871',
#   'W01001759',
#   'W01001817',
#   'W01001872',
#   'W01001708',
#   'W01001818',
#   'W01001709',
#   'W01001873',
#   'W01001760',
#   'W01001710',
#   'W01001922',
#   'W01001874',
#   'W01001761',
#   'W01001711',
#   'W01001875',
#   'W01001762',
#   'W01001821',
#   'W01001712',
#   'W01001876',
#   'W01001764',
#   'W01001822',
#   'W01001713',
#   'W01001877',
#   'W01001765',
#   'W01001823',
#   'W01001714',
#   'W01001878',
#   'W01001766',
#   'W01001824',
#   'W01001715',
#   'W01001879',
#   'W01001767',
#   'W01001825',
#   'W01001716',
#   'W01001880',
#   'W01001768',
#   'W01001826',
#   'W01001717',
#   'W01001881',
#   'W01001769',
#   'W01001827',
#   'W01001718',
#   'W01001882',
#   'W01001883',
#   'W01001719',
#   'W01001884',
#   'W01001720',
#   'W01001885',
#   'W01001721',
#   'W01001886',
#   'W01001770',
#   'W01001722',
#   'W01001887',
#   'W01001771',
#   'W01001724',
#   'W01001888',
#   'W01001772',
#   'W01001725',
#   'W01001889',
#   'W01001773',
#   'W01001726',
#   'W01001890',
#   'W01001774',
#   'W01001828',
#   'W01001891',
#   'W01001775',
#   'W01001939',
#   'W01001829',
#   'W01001892',
#   'W01001730',
#   'W01001776',
#   'W01001830',
#   'W01001940',
#   'W01001731',
#   'W01001777',
#   'W01001831',
#   'W01001941',
#   'W01001894',
#   'W01001732',
#   'W01001778',
#   'W01001832',
#   'W01001942',
#   'W01001895',
#   'W01001733',
#   'W01001779',
#   'W01001833',
#   'W01001943',
#   'W01001896',
#   'W01001734',
#   'W01001780',
#   'W01001834',
#   'W01001944',
#   'W01001735',
#   'W01001781',
#   'W01001835',
#   'W01001736',
#   'W01001782',
#   'W01001836',
#   'W01001946',
#   'W01001737',
#   'W01001783',
#   'W01001837',
#   'W01001947',
#   'W01001738',
#   'W01001784',
#   'W01001838',
#   'W01001948',
#   'W01001739',
#   'W01001785',
#   'W01001839',
#   'W01001949',
#   'W01001740',
#   'W01001786',
#   'W01001840',
#   'W01001950',
#   'W01001741',
#   'W01001787',
#   'W01001788',
#   'W01001789',
#   'W01001790',
#   'W01001791',
#   'W01001792',
#   'W01001793',
#   'W01001794',
#   'W01001795',
#   'W01001796',
#   'W01001797',
#   'W01001798',
#   'W01001799',
#   'W01001800',
#   'W01001802',
#   'W01001803',
#   'W01001804',
#   'W01001805',
#   'W01001806',
#   'W01001807',
#   'W01001808',
#   'W01001841',
#   'W01001742',
#   'W01001842',
#   'W01001743',
#   'W01001843',
#   'W01001951',
#   'W01001744',
#   'W01001844',
#   'W01001952',
#   'W01001745',
#   'W01001846',
#   'W01001953',
#   'W01001746',
#   'W01001847',
#   'W01001954',
#   'W01001747',
#   'W01001848',
#   'W01001748',
#   'W01001849',
#   'W01001749',
#   'W01001850',
#   'W01001750',
#   'W01001851',
#   'W01001751',
#   'W01001852',
#   'W01001694',
#   'W01001853',
#   'W01001752',
#   'W01001695',
#   'W01001854',
#   'W01001753',
#   'W01001696',
#   'W01001855',
#   'W01001754',
#   'W01001697',
#   'W01001856',
#   'W01001755',
#   'W01001698',
#   'W01001699',
#   'W01001702',
#   'W01001703',
#   'W01001857',
#   'W01001858',
#   'W01001859',
#   'W01001860'],
#  'Carlisle': ['E01019244',
#   'E01019245',
#   'E01019246',
#   'E01019247',
#   'E01019194',
#   'E01019248',
#   'E01019195',
#   'E01019196',
#   'E01019197',
#   'E01019198',
#   'E01019252',
#   'E01019199',
#   'E01019253',
#   'E01019254',
#   'E01019255',
#   'E01019188',
#   'E01019189',
#   'E01019190',
#   'E01019191',
#   'E01019192',
#   'E01019193',
#   'E01019204',
#   'E01019205',
#   'E01019206',
#   'E01019207',
#   'E01019208',
#   'E01019209',
#   'E01019210',
#   'E01019211',
#   'E01019213',
#   'E01019215',
#   'E01019216',
#   'E01019217',
#   'E01019218',
#   'E01019220',
#   'E01019221',
#   'E01019222',
#   'E01019223',
#   'E01019230',
#   'E01019231',
#   'E01019232',
#   'E01019233',
#   'E01019234',
#   'E01019235',
#   'E01019236',
#   'E01019237',
#   'E01019241',
#   'E01019242',
#   'E01019243'],
#   'E01031839',
#   'E01031790',
#   'E01031840',
#   'E01031791',
#   'E01031792',
#   'E01031793',
#   'E01031794',
#   'E01031795',
#   'E01031796'],
#  'York': ['E01013404',
#   'E01013405',
#   'E01013406',
#   'E01013407',
#   'E01013408',
#   'E01013409',
#   'E01013410',
#   'E01013411',
#   'E01013412',
#   'E01013413',
#   'E01013414',
#   'E01013416',
#   'E01013417',
#   'E01013418',
#   'E01013419',
#   'E01013420',
#   'E01013428',
#   'E01013429',
#   'E01013431',
#   'E01013432',
#   'E01013433',
#   'E01013434',
#   'E01013435',
#   'E01013441',
#   'E01013442',
#   'E01013443',
#   'E01013444',
#   'E01013445',
#   'E01013446',
#   'E01013447',
#   'E01013448',
#   'E01013449',
#   'E01013353',
#   'E01013354',
#   'E01013355',
#   'E01013356',
#   'E01013357',
#   'E01013358',
#   'E01013359',
#   'E01013360',
#   'E01013361',
#   'E01013362',
#   'E01013363',
#   'E01013364',
#   'E01013365',
#   'E01013366',
#   'E01013368',
#   'E01013369',
#   'E01013378',
#   'E01013379',
#   'E01013380',
#   'E01013381',
#   'E01013382',
#   'E01013383',
#   'E01013384',
#   'E01013385',
#   'E01013386',
#   'E01013387',
#   'E01013388',
#   'E01013389',
#   'E01013390',
#   'E01013391',
#   'E01013392',
#   'E01013393',
#   'E01013394',
#   'E01013395',
#   'E01013396',
#   'E01013397',
#   'E01013398',
#   'E01013399',
#   'E01013400',
#   'E01013401',
#   'E01013402',
#   'E01013403',
#   'E01013335',
#   'E01013336',
#   'E01013337',
#   'E01013338',
#   'E01013339',
#   'E01013343',
#   'E01013344',
#   'E01013345',
#   'E01013346',
#   'E01013347',
#   'E01013348',
#   'E01013349',
#   'E01013350',
#   'E01033067',
#   'E01033068',
#   'E01033069',
#   'E01033070']}

# %%
# %store IMD_city
# Out:
# Stored 'IMD_city' (dict)

# %%
len(IMD_city)
# Out:
# 112

# %%
# json.dump(cityPop,open('City_pop_england.json','w'))

# %%
# %store monthly_borough_savings
# %store monthly_borough_dosage
# %store monthly_borough_costs

# %%
# pkl.dump(monthly_borough_savings,open('the_three_city_savings.pkl','wb'))

# pkl.dump(monthly_borough_dosage,open('the_three_city_dosage.pkl','wb'))

# pkl.dump(monthly_borough_costs,open('the_three_city_costs.pkl','wb'))

# %%
# pkl.dump(monthly_borough_savings,open('the_three_savings.pkl','wb'))

# pkl.dump(monthly_borough_dosage,open('the_three_dosage.pkl','wb'))

# pkl.dump(monthly_borough_costs,open('the_three_costs.pkl','wb'))

# %%
# monthly_borough_savings = pkl.load(open('10_Cat_savings.pkl','rb'))

# monthly_borough_dosage  = pkl.load(open('the_three_dosage.pkl','rb'))

# monthly_borough_costs = pkl.load(open('the_three_costs.pkl','rb'))

# %%
# len(monthly_borough_savings['opioids']['201201'])

# %%
total_savings = {k:0 for k in selectedKeys}
for k in total_savings.keys():
    disease_saving= monthly_borough_savings[k]
    for month in disease_saving:
        total_savings[k]+= np.sum(disease_saving[month].values())
    
print total_savings
# Out:
# {'opioids': 7490771.694831205}

# %%
import operator
sorted(total_savings.items(), key=operator.itemgetter(1))
# Out:
# [('opioids', 7490771.694831205)]

# %%
# sorted(monthly_borough_savings['Vitamins'].keys())

# %%
disease = 'opioids'
cityOverSpending = {}
savings = monthly_borough_savings[disease]
for k in savings:
    for city in savings[k]:
        if city not in cityOverSpending:
            cityOverSpending[city] = 0
        else: 
            cityOverSpending[city]+=savings[k][city]
# for k in cityOverSpending:

# %%
disease = 'opioids'
cityDosage = {}
savings = monthly_borough_dosage[disease]
for k in savings:
    for city in savings[k]:
        if city not in cityDosage:
            cityDosage[city] = 0
        else: 
            cityDosage[city]+=savings[k][city]

# %%
# cityDosage

# %%
len(cityDosage)
# Out:
# 109

# %%
common = list(set(cityOverSpending.keys()).intersection(cityPop.keys()))
len(common)

def label_point(x, y, val, ax ):
    a = pd.concat({'x': pd.Series(x), 'y':  pd.Series(y), 'val': pd.Series(val)}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x'], point['y'], str(point['val']),fontsize=15)

predict = []
gt = []
names = []
selected_city = ['Birmingham', 'London' , 'Bolton' , 'Leicester' , 'Blackpool' , 'Oxford' , 'Cambridge' , 'Nottingham' ]
for k in common:
    predict.append(np.log(cityPop[k]))
    gt.append(np.log(cityOverSpending[k]))
    if k in selected_city:
        names.append(k)
    else:
        names.append('')

# %%
predict_dosage = []
gt_dosage = []
gt_IMD = []
names = []
selected_city = ['Birmingham', 'London' , 'Bolton' , 'Leicester' , 'Blackpool' , 'Oxford' , 'Cambridge' , 'Nottingham' ]
for k in common:
    predict_dosage.append(np.log(cityPop[k]))
    gt_dosage.append(np.log(cityDosage[k]))
    gt_IMD.append(IMD_city[k])
    if k in selected_city:
        names.append(k)
    else:
        names.append('')

# %%
totalOverSpend = np.log(np.sum(cityOverSpending.values()))
logSumOverspend = np.sum([np.log(k) for k in cityOverSpending.values()])

totalCityPop = np.log(np.sum(cityPop.values()))
logSumPop = np.sum([np.log(k) for k in cityPop.values()])
print totalOverSpend , totalCityPop
print logSumOverspend , logSumPop

normalized_over = {}
for k in common:
    normalized_over[k] = (np.log(cityOverSpending[k])/logSumOverspend) / (np.log(cityPop[k])/logSumPop)
import operator
sorted_over = sorted(normalized_over.items(), key=operator.itemgetter(1))
print ([(k[0],(cityOverSpending[k[0]]/cityPop[k[0]])*1000,cityPop[k[0]]) for k in  sorted_over[:11]])

print ([(k[0],(cityOverSpending[k[0]]/cityPop[k[0]])*1000,cityPop[k[0]]) for k in  sorted_over[-10:]])
# print sorted_over[-10:]
# Out:
# 15.762041848686618 17.068028139431004
# 1167.087992595141 1291.1417406968053
# [('Oxford', 104.9159245973747, 161810), ('Bath', 130.45832517998494, 96154), ('Slough', 136.75882811287283, 149660), ('Bedford', 153.72021238298234, 90384), ('St Albans', 164.40732420810676, 82667), ('Derby', 139.90370214219985, 258462), ('Crawley', 161.9725645202622, 108302), ('High Wycombe', 162.96985304383767, 104398), ('Grimsby', 168.54474713053082, 88386), ('Solihull', 165.36285958547896, 106222), ('Watford', 164.53348415493423, 133212)]
# [('Salford', 587.3007677098981, 88419), ('Gillingham', 589.330246293406, 106709), ('Eastbourne', 590.3377671415954, 109604), ('Maidstone', 640.0477627559312, 108832), ('Bolton', 649.0611561137512, 172631), ('Liverpool', 657.0793876342423, 554126), ('Birkenhead', 723.4168717116513, 88496), ('Rochdale', 723.0561274952177, 107570), ('Mansfield', 820.0568191077771, 78022), ('St Helens', 879.238081370782, 105197)]

# %%
totalDosage = np.log(np.sum(cityDosage.values()))
logSumDosage = np.sum([np.log(k) for k in cityDosage.values()])

totalCityPop = np.log(np.sum(cityPop.values()))
logSumPop = np.sum([np.log(k) for k in cityPop.values()])
print totalDosage , totalCityPop
print logSumDosage , logSumPop

normalized_dosage = {}
for k in common:
    normalized_dosage[k] = (np.log(cityDosage[k])/logSumDosage) / (np.log(cityPop[k])/logSumPop)
import operator
sorted_dosage = sorted(normalized_dosage.items(), key=operator.itemgetter(1))
# print sorted_dosage[:11]

# print sorted_dosage[-10:]
print ([(k[0],(cityDosage[k[0]]/cityPop[k[0]])*1000,cityPop[k[0]]) for k in  sorted_dosage[:11]])

print ([(k[0],(cityDosage[k[0]]/cityPop[k[0]])*1000,cityPop[k[0]]) for k in  sorted_dosage[-10:]])
# print sorted_over[-10:]
# Out:
# 22.66105582122303 17.068028139431004
# 1921.9578092278377 1291.1417406968053
# [('London', 127189.97841181028, 8269658), ('Birmingham', 264180.0205861437, 1093675), ('Watford', 130266.42885384604, 133212), ('Bath', 117487.94273986625, 96154), ('Sheffield', 241321.13765487215, 522029), ('Leicester', 224051.6572081432, 390434), ('Reading', 191817.9354945236, 248665), ('Bristol', 272054.3827721889, 541934), ('Woking', 153146.089817041, 100955), ('Leeds', 315173.88521443267, 479040), ('Cambridge', 189146.9805058549, 147973)]
# [('Wigan', 484661.74506145157, 85664), ('Middlesbrough', 740166.7229613996, 175368), ('St Helens', 563466.2818239009, 105197), ('Rochdale', 583590.6687085762, 107570), ('Scunthorpe', 503214.044300185, 80974), ('Gateshead', 676952.2514254715, 119487), ('Mansfield', 624125.6143906821, 78022), ('Stockton-on-Tees', 652567.6782776065, 82186), ('South Shields', 634832.241433553, 75544), ('Hartlepool', 820199.6845753568, 88004)]

# %%
IMD = []
ratio_over = []
for k in common:
    IMD.append(IMD_city[k])
    ratio_over.append(normalized_over[k])
    
pearsonr(IMD, ratio_over)
# Out:
# (0.3497450825641892, 0.00019316227534595383)

# %%
IMD = []
ratio_dosage = []
for k in common:
    IMD.append(IMD_city[k])
    ratio_dosage.append(normalized_dosage[k])
    
pearsonr(IMD, ratio_dosage)
# Out:
# (0.24399194616603886, 0.010565591499583827)

# %%
dict_dosage = {'IMD' : [], 'OME_consumption': [] , 'population': [] , 'savings_upper_bound' : [] , 'city' : []} 

for k in common:
    dict_dosage['IMD'].append(IMD_city[k])
    dict_dosage['OME_consumption'].append(cityDosage[k])
    dict_dosage['population'].append(cityPop[k])
    dict_dosage['savings_upper_bound'].append(cityOverSpending[k])
    dict_dosage['city'].append(k)
dosage_df = pd.DataFrame.from_dict(dict_dosage)

# %%
dosage_df.head()
# Out:
#       IMD  OME_consumption          city  population  savings_upper_bound
# 0  17.743     3.292810e+07    Gillingham      106709         62886.841252
# 1  28.608     3.556868e+07  Peterborough      163769         63756.026037
# 2  35.095     2.462777e+07        Dudley       77431         19242.310734
# 3  20.532     6.968085e+07       Ipswich      145218         57599.876792
# 4  38.723     6.277685e+07      Rochdale      107570         77779.147635

# %%
# dosage_df.to_csv('scratchpad/city_over_dosage_ome.csv')

# %%
pearsonr(dosage_df['dosage'],dosage_df['population'])
# Out:
# (0.851939490638875, 7.777942788221253e-32)

# %%
pearsonr(dosage_df['over'],dosage_df['IMD'])
# Out:
# (0.33487497213303236, 0.0003719439410416148)

# %%
import statsmodels.api as sm
from scipy.stats import pearsonr
from sklearn import preprocessing
dosage_df['interaction'] = dosage_df['IMD']*dict_dosage['population']
x_dims = ['population']
y_dim = ['over']

min_max_scaler = preprocessing.MinMaxScaler() 

Y = np.array(dosage_df[y_dim].values,dtype=np.float32)
X = np.array(dosage_df[x_dims].values,dtype=np.float32)

X  = sm.add_constant(X)
# X = min_max_scaler.fit_transform(X)
# Y = min_max_scaler.fit_transform(Y)
print(x_dims)
model = sm.OLS(Y, X).fit()

pred = model.predict(X)
model.summary()
# Out:
# ['population']
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     207.0
# Date:                Tue, 19 Jan 2021   Prob (F-statistic):           9.18e-27
# Time:                        16:49:28   Log-Likelihood:                -63.603
# No. Observations:                 109   AIC:                             131.2
# Df Residuals:                     107   BIC:                             136.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1357      0.736      0.184      0.854      -1.323       1.595
# x1             0.8925      0.062     14.387      0.000       0.769       1.015
# ==============================================================================
# Omnibus:                        1.189   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.552   Jarque-Bera (JB):                1.244
# Skew:                          -0.179   Prob(JB):                        0.537
# Kurtosis:                       2.618   Cond. No.                         210.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import statsmodels.api as sm
from scipy.stats import pearsonr
from sklearn import preprocessing
dosage_df['interaction'] = dosage_df['IMD']*dict_dosage['population']
x_dims = ['population','IMD','interaction']
y_dim = ['dosage']

min_max_scaler = preprocessing.MinMaxScaler() 

Y = np.array(dosage_df[y_dim].values,dtype=np.float32)
X = np.array(dosage_df[x_dims].values,dtype=np.float32)

X  = sm.add_constant(X)
# X = min_max_scaler.fit_transform(X)
# Y = min_max_scaler.fit_transform(Y)
print(x_dims)
model = sm.OLS(Y, X).fit()

pred = model.predict(X)
model.summary()
# Out:
# ['population', 'IMD', 'interaction']
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     140.1
# Date:                Tue, 19 Jan 2021   Prob (F-statistic):           1.44e-36
# Time:                        16:49:44   Log-Likelihood:                -26.005
# No. Observations:                 109   AIC:                             60.01
# Df Residuals:                     105   BIC:                             70.78
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.1412      1.763      4.051      0.000       3.646      10.637
# x1             0.8459      0.150      5.625      0.000       0.548       1.144
# x2             0.0319      0.065      0.492      0.624      -0.097       0.160
# x3            -0.0010      0.006     -0.173      0.863      -0.012       0.010
# ==============================================================================
# Omnibus:                        1.421   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.491   Jarque-Bera (JB):                1.284
# Skew:                          -0.118   Prob(JB):                        0.526
# Kurtosis:                       2.523   Cond. No.                     1.75e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.75e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from sklearn.metrics import r2_score
r2_score(predict,gt)
# Out:
# -2.2589436226306367

# %%
from sklearn.metrics import r2_score
r2_score(predict_dosage,gt_dosage)
# Out:
# -72.62320799944786

# %%
from scipy.stats import linregress

corr = pearsonr(predict, gt)
print corr

slope, intercept, r_value, p_value, std_err = linregress(x=gt,y=predict)

print slope,  intercept , r_value , p_value , std_err
# Out:
# (0.8119169248614544, 9.178958235202088e-27)
# 0.7386424722070526 3.936522757460219 0.8119169248614545 9.178958235201961e-27 0.05134223756996747

# %%
from scipy.stats import linregress

corr = pearsonr(predict_dosage, gt_dosage)
print corr

slope_dosage, intercept_dosage, r_value_dosage, p_value_dosage, std_err_dosage = linregress(x=gt_dosage,y=predict_dosage)

print slope_dosage,  intercept_dosage , r_value_dosage , p_value_dosage , std_err_dosage
# Out:
# (0.851939490638875, 7.777942788221253e-32)
# 0.8380713984421161 -2.9320745709129774 0.8519394906388749 7.777942788221336e-32 0.04979817149724149

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
p = sns.regplot(x=predict,y=gt,ax=ax)
ax.set_xlabel("ln(Population)",fontsize=25)
ax.set_ylabel("$ln(s_{ub}(a))$",fontsize=25)
# ax.set_title("Opioids",fontsize=25)
plt.xticks(fontsize = 20 )
plt.yticks(fontsize = 20 )
label_point(predict , gt , names , ax)
ax.annotate(r"$\beta$" +": " +  str(slope)[:4], xy=(0.1, 0.8), xycoords='axes fraction',fontsize = 20)
# ax.annotate(r"$\alpha$" +": " +  str(intercept)[:4], xy=(0.1, 0.7), xycoords='axes fraction',fontsize = 20)
ax.annotate(r"$R^2$" +": " +  str(r_value**2)[:4], xy=(0.1, 0.7), xycoords='axes fraction',fontsize = 20)
# Out:
# Text(0.1,0.7,'$R^2$: 0.65')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
p = sns.regplot(x=predict_dosage,y=gt_dosage,ax=ax)
ax.set_xlabel("ln(Population)",fontsize=25)
ax.set_ylabel("$ln({u}(a))$",fontsize=25)
# ax.set_title("Opioids",fontsize=25)
plt.xticks(fontsize = 20 )
plt.yticks(fontsize = 20 )
label_point(predict_dosage , gt_dosage , names , ax)
ax.annotate(r"$\beta$" +": " +  str(slope_dosage)[:4], xy=(0.1, 0.8), xycoords='axes fraction',fontsize = 20)
# ax.annotate(r"$\alpha$" +": " +  str(intercept)[:4], xy=(0.1, 0.7), xycoords='axes fraction',fontsize = 20)
ax.annotate(r"$R^2$" +": " +  str(r_value_dosage**2)[:4], xy=(0.1, 0.7), xycoords='axes fraction',fontsize = 20)
# Out:
# Text(0.1,0.7,'$R^2$: 0.72')

# %%
cityOverSpending
# Out:
# {'Barnsley': 30845.6584463876,
#  'Basildon': 42348.44002572297,
#  'Basingstoke': 38888.680098802346,
#  'Bath': 12544.08979935627,
#  'Bedford': 13893.847676023475,
#  'Birkenhead': 64019.4994789943,
#  'Birmingham': 271424.7056001261,
#  'Blackburn': 29896.134460876463,
#  'Blackpool': 40869.35670685795,
#  'Bolton': 112048.07644107298,
#  'Bournemouth': 49600.94395814398,
#  'Bracknell': 15745.330138563655,
#  'Bradford': 101169.31299290528,
#  'Brighton and Hove': 89870.67980852048,
#  'Bristol': 199497.45236849826,
#  'Burnley': 23368.10404202644,
#  'Burton upon Trent': 16667.580126657733,
#  'Bury': 28590.949676953252,
#  'Cambridge': 32930.61627868646,
#  'Carlisle': 29601.61887909033,
#  'Chatham': 34768.521836482185,
#  'Chelmsford': 50293.850051419184,
#  'Cheltenham': 35556.13427330427,
#  'Chester': 27657.509594239153,
#  'Chesterfield': 30862.980736907502,
#  'Colchester': 33238.446947558885,
#  'Coventry': 85151.47861795303,
#  'Crawley': 17541.952682673436,
#  'Darlington': 26059.625886606318,
#  'Derby': 36159.790663077256,
#  'Doncaster': 58053.92277752345,
#  'Dudley': 19242.31073440239,
#  'Eastbourne': 64703.38062978742,
#  'Exeter': 36795.78482798474,
#  'Gateshead': 33910.592251036665,
#  'Gillingham': 62886.84125172306,
#  'Gloucester': 60403.37535844868,
#  'Grimsby': 14896.996019879098,
#  'Guildford': 15631.179037037871,
#  'Halifax': 31902.7071707784,
#  'Harlow': 46895.05087260713,
#  'Harrogate': 24822.28931548814,
#  'Hartlepool': 41020.198797946156,
#  'Hastings': 33453.19883830952,
#  'Hemel Hempstead': 17627.04579894972,
#  'High Wycombe': 17013.726718070568,
#  'Huddersfield': 55428.84759783387,
#  'Ipswich': 57599.87679217574,
#  'Kingston upon Hull': 95477.25657577976,
#  'Leeds': 181072.67165831436,
#  'Leicester': 75414.92389273526,
#  'Lincoln': 54815.37225584284,
#  'Liverpool': 364104.7727522121,
#  'London': 867499.3310234868,
#  'Luton': 45804.276914956565,
#  'Maidstone': 69657.6781162535,
#  'Manchester': 214520.660924654,
#  'Mansfield': 63982.473140426984,
#  'Middlesbrough': 77088.79715303397,
#  'Milton Keynes': 58631.30114454359,
#  'Newcastle upon Tyne': 76204.87619377834,
#  'Newcastle-under-Lyme': 17903.82278735019,
#  'Northampton': 76133.9224073551,
#  'Norwich': 102824.83213372079,
#  'Nottingham': 100858.98517721315,
#  'Nuneaton': 32587.196573583897,
#  'Oldham': 24482.91674846122,
#  'Oxford': 16976.4457591012,
#  'Peterborough': 63756.02603743639,
#  'Plymouth': 109792.75044440739,
#  'Poole': 51583.995810467626,
#  'Portsmouth': 53690.89552493613,
#  'Preston': 33349.65921439895,
#  'Reading': 63518.58275118717,
#  'Redditch': 40622.71919793541,
#  'Rochdale': 77779.14763466056,
#  'Rotherham': 34088.4341426168,
#  'Salford': 51928.546580141476,
#  'Scunthorpe': 22408.4782277222,
#  'Sheffield': 183311.01500998574,
#  'Shrewsbury': 20656.622322523337,
#  'Slough': 20467.326215372545,
#  'Solihull': 17565.173670888747,
#  'South Shields': 19580.655096648836,
#  'Southampton': 136226.9889522979,
#  'Southend-on-Sea': 67491.77631855657,
#  'Southport': 31054.878637464713,
#  'St Albans': 13591.06027031156,
#  'St Helens': 92493.20844596215,
#  'Stevenage': 18441.234531472026,
#  'Stockport': 27106.130660414507,
#  'Stockton-on-Tees': 37774.28637298841,
#  'Stoke-on-Trent': 107098.6165746375,
#  'Sunderland': 70973.26225278742,
#  'Sutton Coldfield': 20669.550911369857,
#  'Swindon': 83559.10192411071,
#  'Telford': 39521.5009554766,
#  'Wakefield': 51582.76943077919,
#  'Walsall': 32101.587932995768,
#  'Warrington': 53923.72219920921,
#  'Watford': 21917.8344912471,
#  'West Bromwich': 33264.340459299565,
#  'Weston-Super-Mare': 37072.27074436139,
#  'Wigan': 36562.62343782168,
#  'Woking': 38559.27799529726,
#  'Wolverhampton': 45824.87884363203,
#  'Worcester': 48743.90889245042,
#  'Worthing': 22796.099221237208,
#  'York': 42457.19755345188}

# %%
keys = ['opioids']
allCosts = {}
for k in keys:
    allCosts[k] = 0.0
    for m in monthly_borough_savings[k]:
        allCosts[k]+= np.sum(monthly_borough_savings[k][m].values())

# %%
sum(allCosts.values())
# Out:
# 7490771.694831205

# %%
monthly_borough_costs_slice = monthly_borough_costs['opioids']
monthly_borough_savings_slice = monthly_borough_savings['opioids']
monthly_borough_dosage_slice = monthly_borough_dosage['opioids']

# %%
total_monthly_costs = {}
for k in monthly_borough_costs_slice:
    total_monthly_costs[k] = {}
    for b in monthly_borough_costs_slice[k]:
        scale = float( population_borough[b])/1000.0
        total_monthly_costs[k][b] = monthly_borough_costs_slice[k][b]*scale
        
total_monthly_costs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-e43397582fbc> in <module>()
#       3     total_monthly_costs[k] = {}
#       4     for b in monthly_borough_costs_slice[k]:
# ----> 5         scale = float( population_borough[b])/1000.0
#       6         total_monthly_costs[k][b] = monthly_borough_costs_slice[k][b]*scale
#       7
#
# KeyError: 'Kingston upon Hull'

# %%
totalCost = {}
totalOverspend = {}
for k in monthly_borough_savings_slice:
    totalOverspend[k] = np.sum(monthly_borough_savings_slice[k].values())
    totalCost[k] = np.sum(total_monthly_costs[k].values())

# %%
np.sum(totalCost.values()) , np.sum(totalOverspend.values())

# %%
UKwide_opioid = {}
UKUKwide_opioid_costs = {}
for k in monthly_borough_savings_slice:
    UKwide_opioid[k] = sum(monthly_borough_savings_slice[k].values())
for k in monthly_borough_costs_slice:
    total = []
    for b in monthly_borough_costs_slice[k]:
        scale = float( population_borough[b])/1000.0
        total.append(monthly_borough_costs_slice[k][b]*scale)
    UKUKwide_opioid_costs[k] = total

# %%
all_overspend = {}
all_overspend['savings'] = totalOverspend
all_overspend['costs'] = totalCost

# %%
# all_overspend

# %%
# %store opioid_overspend
# %store all_overSpend

# %%
# all_monthly_borough_savings = monthly_borough_savings

# %store all_monthly_borough_savings
# %store -r monthly_borough_savings

# %%
# %store -r monthly_borough_savings

# %%
IMD_District = json.load(open('District_IMD_scores_life_values.json','rb'))

# %%
IMD_District['Wirral']

# %%
savings = {}
for month in monthly_borough_savings_slice:
    for dist in monthly_borough_savings_slice[month]:
        if dist not in savings:
            savings[dist] = 0.0
        else:
            savings[dist]+=monthly_borough_savings_slice[month][dist]
dose = {}
for month in monthly_borough_dosage_slice:
    for dist in monthly_borough_dosage_slice[month]:
        if dist not in dose:
            dose[dist] = 0.0
        else:
            dose[dist]+=monthly_borough_dosage_slice[month][dist]

cost = {}
for month in total_monthly_costs:
    for dist in total_monthly_costs[month]:
        if dist not in cost:
            cost[dist] = 0.0
        else:
            cost[dist]+=total_monthly_costs[month][dist]

            
dict_saving = {'Name':[],'Savings':[] , 'Dosage':[] , 'Density' : [] , 'Seniors' : [] , 'IMD' : [] , 'TotalCost':[]}
for s in savings:
    dict_saving['Name'].append(s)
    dict_saving['Savings'].append(savings[s])
    dict_saving['TotalCost'].append(cost[s])
    dict_saving['Dosage'].append(dose[s])
    dict_saving['Density'].append(IMD_District[s]['pop_density'])
    dict_saving['Seniors'].append(IMD_District[s]['senior_pop'])
    dict_saving['IMD'].append(IMD_District[s]['aggregate_IMD'])



savings_df = pd.DataFrame(dict_saving)

# %%
savings_df

# %%
england = gp.read_file('../BL_Work/Local_Authority_Districts_December_2017_Ultra_Generalised_Clipped_Boundaries_in_United_Kingdom_WGS84.shp')

# %%
england.head()

# %%
merged = england.set_index('lad17nm').join(savings_df.set_index('Name'))
merged = merged[np.isfinite(merged['Savings'])]

# %%
merged

# %%
merged.to_csv('anti_dep_borough_2016_data.csv')

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'Savings'
vmin, vmax = min(savings_df['Savings']) , max(savings_df['Savings'])

fig, ax = plt.subplots(1, figsize=(18, 12))
merged.plot(column=variable, cmap='Reds', linewidth=1, ax=ax, edgecolor='0.8')
ax.axis('off')
ax.set_title('Overspending for opioids', fontdict={'fontsize': 25, 'fontweight' : 20})
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)
cbar.ax.yaxis.offsetText.set(size=20)
cbar.ax.tick_params(labelsize=30)

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'Dosage'
vmin, vmax = min(savings_df['Dosage']) , max(savings_df['Dosage'])

fig, ax = plt.subplots(1, figsize=(18, 12))
merged.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')
ax.axis('off')
ax.set_title('Normalized dosages per 1000 (2010-2019)', fontdict={'fontsize': 25, 'fontweight' : 5})
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

# %%
standardized_merged = merged.copy()

# %%
def normalize(df,feature_names):
    result = df.copy()
    for feature_name in feature_names:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result

# %%
standardized_merged = normalize(merged , ['Savings','Density','Dosage','IMD','Seniors'])

# %%
standardized_merged.head()

# %%
corr = pearsonr(standardized_merged['Dosage'], standardized_merged['IMD'])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
sns.regplot(x='Dosage',y='IMD',data=standardized_merged)
ax.set_title("IMD Vs Relative normalized dosage for Anti depressants" , fontsize=20)
ax.set_xlabel("Relative normalized dosage",fontsize=20)
ax.set_ylabel("Normalized IMD",fontsize=20)
ax.annotate("Corr: " +  str(corr[0])[:4],  xy=(0.8, 0.2),fontsize = 18)

# %%
corr = pearsonr(standardized_merged['Savings'], standardized_merged['IMD'])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
sns.regplot(x='Savings',y='IMD',data=standardized_merged)
ax.set_title("IMD Vs Overspending across all Drugs" , fontsize=20)
ax.set_xlabel("Normalized Overspending",fontsize=20)
ax.set_ylabel("Normalized IMD",fontsize=20)
ax.annotate("Corr: " +  str(corr[0])[:4],  xy=(0.8, 0.2),fontsize = 18)

# %%
corr = pearsonr(standardized_merged['Savings'], standardized_merged['Seniors'])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
sns.regplot(x='Savings',y='Seniors',data=standardized_merged)
ax.set_title("Senior population Vs Savings from Generics: Opioids" , fontsize=20)
ax.set_xlabel("Normalized Savings",fontsize=20)
ax.set_ylabel("Normalized Senior population",fontsize=20)
ax.annotate("Corr: " +  str(corr[0])[:4],  xy=(0.8, 0.2),fontsize = 18)

# %%
corr=pearsonr(standardized_merged['Savings'], standardized_merged['Density'])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
sns.regplot(x='Savings',y='Density',data=standardized_merged)
ax.set_title("Population density Vs Overspending" ,fontsize=20)
ax.set_xlabel("Normalized Overspending",fontsize=20)
ax.set_ylabel("Normalized population density",fontsize=20)
ax.annotate("Corr: " +  str(corr[0])[:4],  xy=(0.8, 0.8),fontsize = 18)

# %%
corr=pearsonr(standardized_merged['Dosage'], standardized_merged['Density'])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
sns.regplot(x='Dosage',y='Density',data=standardized_merged)
ax.set_title("Population density Vs Relative Normalized dosage for Anti-depressants" ,fontsize=20)
ax.set_xlabel("Relative normalized  dosage",fontsize=20)
ax.set_ylabel("Normalized population density",fontsize=20)
ax.annotate("Corr: " +  str(corr[0])[:4],  xy=(0.8, 0.8),fontsize = 18)

# %%
pearsonr(standardized_merged['Dosage'], standardized_merged['Seniors'])

# %%
sns.regplot(x='Savings',y='Seniors',data=standardized_merged)

# %%
monthlySavings = {}
for k in monthly_borough_savings:
    monthlySavings[k] = np.median(monthly_borough_savings[k].values())
    
    
monthlyCosts = {}
for k in monthly_borough_costs:
    monthlyCosts[k] = np.median(monthly_borough_costs[k].values())

# %%
months = sorted(all_overspend['savings'].keys())

# %%
overspend = [all_overspend['savings'][k]/1000000.0 for k in months]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18, 10)
sns.set_style("white")
sns.lineplot(y=overspend,x=np.arange(0,len(months),1))
# sns.lineplot(y=savings_df['diabetes_over'],x=np.arange(0,len(savings_df),1))
# sns.lineplot(y=savings_df['opioid_over'],x=np.arange(0,len(savings_df),1))
ax = plt.gca()

# plt.xticks(np.arange(0,len(months)+1, 2.0))
labels= [months[2*i] for i in range(0,len(months)/2)]
plt.xticks(np.arange(0,len(months) ,2),labels,rotation=90,fontsize= 15)
plt.yticks(fontsize= 15)
# plt.legend(['Overspending for Depression', 'Overspending for Diabetes', 'Overspending for Opioids'], fontsize = 16)
plt.xlabel("Year and month  (YYYYMM) ",fontsize=20)
plt.ylabel("Overspending in Million Sterling pounds",fontsize=20)
